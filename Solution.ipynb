# %% [markdown]
# ### Task 1: Import Modules

# %%
from pytube import extract
from heapq import nlargest
from youtube_transcript_api import YouTubeTranscriptApi
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %% [markdown]
# ### Task 2: Get ID of the Youtube Video

# %%
url = 'https://www.youtube.com/watch?v=DhkjfTTp_e0&t=1395s'
video_id = extract.video_id(url)
video_id
# Out:
# 'DhkjfTTp_e0'

# %% [markdown]
# ### Task 3: Get Transcript of Video

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)
text = ""
for elem in transcript:
    text = text + " " + elem["text"]
text
# Out:
# " if I have to share or if I have to do any kind of you know the image of something so how can I save it any idea so far we talked about doer Hub we talked about how to run a container how to do the image and all those parts and things now my question is if I have to talk about the that we also talked about that how we can build a image and push it to the docker Hub uh now my question is that if I have to talk about that how can we save the image and the container as a tire file or something we talked about this right yeah we can save it how you told with the command uh like Docker save with this we can save our image as a t file yeah Docker export Docker save command okay yeah those are the two command through which we can do this now today we are going to talk about the docker file okay guys what is Docker file and how does it work in these things right the docker file is nothing it's a text file you know which contains like whatever now the operations you have performed all those operations you are putting up in a text file and jotting down it together okay that is your Docker file okay now those instructions are nothing you know it is basically you execute those instructions you write in the particular order and that is how it is written and it creates the images and these things now let's say that if we have to create a image where you have to install a git right what you do you write Docker build G or Docker image git you will pull and then run the container correct correct yeah yeah now what in our case what I'm am going to do is that I have to run or I have to install the git so for that let's say I will install a operating system name as Alpine what I'll do I'll install the operating system Alpine and I will write that okay how can I install the git now you see this is a example of a Docker file okay I will write Run apk update and Run apk G Now APK add G APK update are what those are the two commands for operating system Alpine okay now you can change it based on the ubu based on any other thing correct yeah now once it is done then we can do what we can build this image how we can build using a Docker build command and we can further tag the image where the things are there now once this is done we can create a container and do the things this will help me to do all the things now the point is how can we build a image how can we do all the steps so create a Docker file go to the server or wherever Docker is installed go [Music] there do like I have done through AWS awss [Music] okay yeah right do minus minus version enter okay uh do do PWD go to any home directory right CD hyphen hyphen just write hyy C Hy CD space Hy enter okay so okay that is let just do CD and enter okay home directory that on fine no problem now here write VI Docker file in capital Docker file scho I write down the paste down the those three commands which I have done sent [Music] over I didn't get you what you said in the chat window the content of a Docker file right okay um listen from Alpine yeah okay P there and then hold on I'll tell you what now with this there is one question in the interview which is asked most of the time that what are the default parameters or the attributes or you know the instruction which you have to pass when you write a dogger file now from is what from will tell you that which image has to be used okay Alpine colum 3.5 is what this a image of Alpine OS with version 3.5 run is a command to run the com this any commands and anything right that is one instruction so from run all these are keywords here okay these are the instruction we'll see further more as and then we will move likewise we have one instruction by which is known as maintainer what it is known as maintainer maintainer those keywords should be in a capital or anything huh those keywords run Capital all capital maintainer is also something which is the author okay after maintainer you can give author which will tell you that maintains this file so li ...

# %% [markdown]
# ### Task 4: Get all Sentences

# %%
nlp = spacy.load('en_core_web_sm')
document = nlp(text)
for sentence in document.sents:
    print(sentence.text)
# Out:
#  if I have to share or if I have to do any kind of you know the image of something
# so how can I save it any idea so far we talked about doer Hub we talked about how to run a container how to do the image and all those parts and things now my question is if I have to talk about the that we also talked about that how we can build a image and push it to the docker Hub uh now my question is that if I have to talk about that how can we save the image and the container as a tire file or something we talked about this
# right
# yeah we can save it how you told with the command uh like Docker save with this we can save our image as a t file
# yeah
# Docker export Docker save command
# okay
# yeah those are the two command through which we can do this now today we are going to talk about the docker file okay guys what is Docker file and how does it work in these things right the docker file is nothing it's a text file you know which contains like whatever now the operations you have performed all those operations you are putting up in a text file and jotting down it together
# okay that is your Docker file
# okay now those instructions are nothing you know it is basically you execute those instructions you write in the particular order and that is how it is written
# and it creates the images and these things now let's say that if we have to create a image where you have to install a git
# right
# what you do you write Docker build G or Docker image git you will pull and then run the container correct correct
# yeah
# yeah
# now what in our case what I'm am going to do is that I have to run or I have to install the git so for that let's say I will install a operating system name as Alpine what I'll do
# I'll install the operating system Alpine
# and I will write that
# okay
# how can I install the git now you see this is a example of a Docker file
# okay I will write Run apk update and Run apk G Now APK add G APK update are what those are the two commands for operating system
# Alpine
# okay now you can change it based on the ubu based on any other thing correct
# yeah now once it is done then we can do what we can build this image how we can build using a Docker build command
# and we can further tag the image where the things are there now once this is done we can create a container and do the things this will help me to do all the things now the point is how can we build a image how can we do all the steps so create a Docker file go to the server or wherever Docker is installed go
# [Music] there do like I have done through AWS awss
# [Music]
# okay
# yeah
# right do minus minus version enter
# okay uh do do PWD go to any home directory right CD hyphen
# hyphen just write hyy C
# Hy CD space Hy enter
# okay
# so okay
# that is let just do CD and enter okay home directory that on fine
# no problem now here write VI Docker file in capital Docker file scho I write down the paste down the those three commands which I have done sent [Music] over I didn't get you what you said in the chat window the content of a Docker file
# right
# okay um listen from Alpine
# yeah
# okay
# P there and then hold on I'll tell you what now with this there is one question in the interview which is asked most of the time that what are the default parameters or the attributes or you know the instruction which you have to pass when you write a dogger file now from is what from will tell you that which image has to be used okay Alpine colum 3.5 is what this a image of Alpine OS with version 3.5 run is a command to run the com this any commands and anything right that is one instruction so from run all these are keywords here
# okay these are the instruction we'll see further more as
# and then we will move likewise we have one instruction by which is known as maintainer what it is known as maintainer maintainer those keywords should be in a capital or anything huh those keywords run Capital all capital maintainer is also something which is the author okay after maintainer you can give author which will tell you that maintains this file so likewise you have different other parameters which we will talk about
# okay now save this file
# okay now Escape colon [Music] WQ see last class only you guys got a good one from like not like any kind of a scolding or something
# but I was telling you guys last class also that you guys are so weak in Linux so far but still you guys are in the same condition one week gone no progress this show that no study done Escape press Escape now press colon WQ lbo W WQ enter if this would be the situation I'm telling you guys to be honest you have to make your limits very strong if you don't have your Linux strongs any interview go for DeVos interview you go for a CO interview Linux Linux Basics are very important these are are Basics
# [Music] actually anyways write a command Docker space build space minus t space now give your dockerhub username here email ID that's okay give rajeswar only SL WR Alpine hyen gate hyen hyphen space dot
# [Music] do do LS here for do one thing move rename the docker file with the only capital D as a [Music] capital hold on how hold on hold on except rajes no one else will tell this to me how can we rename the file in Linux guys if you mind my words right now I don't care mind it
# but it's high time we are doing this course from last three months we are not aware of the command so far we are almost at the end of the course now Shila what is the command to rename the file sha if you're speaking you're speaking on mute with help what is the command
# most anit
# yeah MV command with the help of command
# sorry I was on mute
# yeah
# no
# as now you get the command write MV space give this Docker file name the file which has to be changed the file which has to be changed space a new name what is this I space the new name of the file which has to be written enter
# yeah do LS list out the file now you see the change run that Docker build command again
# okay
# and press up AR why don't why you have to type it over again and again
# yeah hit enter now you see so the syntax of the docker file name was wrong that's why it gave you that error
# okay maximize your screen here what it has done it has basically installed everything with this layers right it has created you know pulled a image in updated the package in my case it is giving error same
# okay
# what error uh error response from demon is not running then service status Docker
# yeah now how can you check uh rajeswari that whether the image has built or not it is running running running SE t dotop hold on one minute
# yeah
# how will you check rajeswari what we have to check image you have created right whether the image is installed or not Imes you have the command
# right
# and you have this thing also you see the imagees created right about a minute ago
# yeah
# so we have this image already created now
# right so your command ran successfully correct
# yeah
# yes
# okay we have been playing around with doer for quite a bit now we were able to start containers and execut a sh inside those containers now the whole point of thing here is that we have to understand this image layering concept okay in the docker file which is again very very important part each and every Docker file which is running here that is what that is a runnable instance of an image right that is a runable instance of an image which is basically how which is basically being done by some more other this
# right the uh image layers and these things now the point is that when you create a parent image or you create an image from a Docker file
# okay the that image is only a read only right means when you create an image
# so or when you run this Docker file it creates some different layers right every command is done via the layer execution means then you have each and every image or each and everything in a Docker file in a read only and whatever the instruction whatever the things you give for those that is being added and all those those layers are created and these are D when you run the command now the instructions like from run copy add and all those things
# okay those adds you to the additional layer mainly the instruction like run copy and add those will help you to add a new layer getting it
# yeah now every layer is read only except the one which is creating a container
# okay the m is the last layer the last layer is called a container layer what is called container layer now example if you run this create another Docker file now if you have to create a separate Docker file you have to give the either change the path and then created okay for now otherwise you have to give a parameter minus 5
# and I think do five
# okay
# so this one you're saying this command which you
# Shar
# huh yeah make a backup of that Docker file which you created earlier and create a new Docker file with the command which I shared right here have to make a backup
# huh how to make a backup P move command you have to write the move command move Docker file and write docker file.
# bku very good rajeswar improve your skill sets otherwise forget run this command I'll be very blunt you might feel it bad right away but this is a you know a bitter truth you have to improve your Linux operating skills
# yeah that command in the chat window now create a new Docker file with the new content which I put out what you are doing how can you create a new file VI Docker file D capital D capital of Docker file enter paste the contents here now guys in this one you see more instructions right apart from from run add you see that how it is copy and all those things are there getting it guys anything to explain any questions no save this how can you save this we did just before sometime in the class that completely shows how con uh with what Focus we are doing it if we are doing just only for sake of running in the cloud that doesn't going to help you escape colon WQ correct very good go ahead build a image with this one
# [Music] now change the name of the image now got no problem forget about the copy file right now others has been B done right now every instruction of the docker file whichever you run that has a layer ID every layer generates a unique layer ID if you see with the step one here it generated a layer ID after that full complete right this
# [Music] one step two this one again generates a layer ID getting it
# yeah now creating now if you want to look over all these layers of these things together now these layers are like again it's all over creating image but the layers are also helpful
# right so write a command Docker history and Docker 23 name Docker space enter WR Docker
# [Music] images was okay write doger history with the blank space for everyone is it the same
# yeah for me it is
# demon ER let's see your error also meanwhile rajes look for the option and tell me what is the option share screen for this also it is giving error response from demo
# yeah
# what word your name is the same the docker file is not the name right first of all check your repository name
# no
# no check your repository name with K contact is it
# the dockerhub account name
# yeah
# yeah
# yeah
# now where do Docker file give SL example Alpine or something then do instead of Docker file just write example get or something tell me Docker build minus t wet K contact SL example git dot
# this one h this is what is the problem it is that lower case letter is required I think I'm that anit what is the what was the problem here in the command H
# yeah he gave the docker file name instead of the image name andila why this Docker file name Docker file won't work why other name will work uh it works on the images only instead of files no rajes maybe we need to go to the directory again and create new what was my question that why there is not working the command
# h
# no
# but now it worked right but had be a difference only the change in the name the docker file is a keyword guys
# yeah
# yeah
# so it's not how can it take you are defining a Docker file with that right anit
# but it is continuously it's pointing with invalid argument and giving the argument there for minus t okay not getting the error if any keyword is cled with any it will take it as a invalid any keyword if I use Docker 1 2 3 then also take it will take ER because Raj took I think doer 2 three it is
# okay it won't give you error at that time tell
# okay it ran now now you see the layer you saw all the things that's okay now
# so for seeing all the history of that and these things run Docker history and run Docker images [Music] no run
# [Music] Docker it's sweet thank you done the docker
# [Music] history and give the image ID hist is spelling is it the right spelling of History image ID first one first one image ID sir the one which you created right now this is what you created [Music] right getting it guys three different layers has been were part of this right do history and copy the image of [Music] alpide see this
# okay anyways
# and we get got it how this layers and how this layer is created the each and every layer is nothing it is a part
# [Music] of this thing
# okay each and every command every instruction which you write in a Docker container that is almost a part of Docker layer getting it
# yeah
# so these are the means how can you identify read and WR layer here very good now the command to visualize the docker layer
# right so what anit is asking is that how can I visualize the layers so the command to visualize the layers is run this command like don't run this command just copy and paste this command and do space and write at your W 1 2 three example I'm saying don't run the command just paste that [Music] command there and do space write your that V so 123
# whatever it is cre slash example G example hyph get whatever the name you have given enter [Music] then we have to give the image name give the image ID rather than
# that space image
# [Music] ID where should I instead of the example
# ID then a command Docker build minus 3 test image do space enter now done Docker images create that copy file create a file hello.
# [Music] text what happened create a file with the name is hello.
# text
# yeah
# I was creating that only file created no it is not created why I create a file the touch command man just write touch
# hello Tex simple command I'm not getting what you asking write touch command t o u c h touch space
# hello.
# TC enter [Music] now that done run the build command again this one
# huh Docker images what is the image name what is the image name guys test image T Test image now run that viralized command and replace the ID with the test image second three for whom you are waiting for Mr with
# yeah
# what what you said s an what I have asked to do run that do command again doy RM the visualiz command run that remove the ID give test image enter sorry remove that uh your with Explorer G complete right run this what it has done it opens the sh like
# but this is a command Docker run minus rmus it minus V that is doing nothing it is mapping the volume volume of server to the cloud
# okay
# I'll check why this command is not working but command work
# okay visualization
# but I'll take care
# okay any question so far
# [Music] so let's create an image right with an instruction add
# yeah tell me what you are asking what I'm
# yeah we saw run instruction we saw add instruction we saw copy instruction so far correct in Docker file any problem with that like uh there are some keywords in Docker file right these keywords you are using from run so where we can get more keywords like which we can get through the some other link okay instruction known as command H CMD which you pass in the brackets
# and you write there like this CMD is nothing that is a command right that
# okay once you install the image and everything run this command top getting it
# yeah now let's move on to the next instruction entry point work di directory something that is a current image
# okay if it is not specified and the default path is root
# [Music] getting it
# yeah
# likewise we have entry point entry point mean that when the things has to work [Music]
# [Applause] now here if you see is this instruction point or entry point what does it says says that go to the bin Eco and there Eco this cont
# right you see label maintainer that tells you the build this image anit now it's your done you share your screen and let's see how much comfort would you have so far actually I am not working on laptop currently no electricity P
# two hours so I joined from Mobile today
# Sila
# yeah sain show me how you will build this image I didn't login at all first of all rajar coming back to [Music] you share your screen writing doctor file is very very important I'll share you a lot of examples also for this create a Docker file take the backup of previous one save this file ma'am rajeswar what happened what you are waiting for [Music] correct now build a image first of all do you have given a name itself wrong you have to give a name at Docker file right you cannot give if you're giving a different name then you have to pass the parameter with minus F and this
# and it sometime doesn't work properly WoW instead of renaming you what you are doing did you do the backup of previous one you got it
# yes we have to using Mo command we have to rename [Music] that you build of the image
# hey rajeswari sorry man' but let me write you the commands that we can't waste time for everyone here
# right sorry use this command repace those commands no no B basically hold on first use this command you didn't put the backup also first use this command then run that command and then run the other Command
# right yes now run other commands so you see this build a image
# right this has built a image a Docker image now let's run this container now do Docker image LS let's see how it is let's verify the [Music] image new test image is there right which I have created now run this run a container as soon as you run a container you will
# [Music] see
# yeah what you said container copy paste a command now you see we have passed this entry point instruction
# right that whenever it executes whenever run give execute this right hash B Echo remember
# yeah
# yeah is the result of the same
# only okay now let's talk about quickly the work di right the work di means the work directory instructions which says that whatever the command you are going to run that has to be run from this directory
# okay that is a present working directory now the whole problem with this is that sorry the whole part with this is that it doesn't create any new layer
# okay like run add copy those creates new layer right work TI doesn't create any new layer but it just adds a metadata information or it just add the information of this into the docker
# that okay this work directory has to be used for running the other commands
# Okay Shila any questions so far no sear
# yeah
# I'll share the document also for all this don't worry guys okay don't worry about that now this run instru right runs instruction is something which executes and which creates a new layer now run can be in two parts right the Run can be done in a two parts one is you can directly write this like like like this run and whatever the command is there the same command or sometimes you write in the brackets and all those with the other syntax also getting it
# yeah if you have to run multiple instructions together at once only you can run like this [Music] also sometimes what happen that you have to create a image with an argument what you have to create an image with an argument example you are creating a image of a Docker file okay where you want to Eco the user
# okay you want to Eco the user and show some messages
# okay now everyone sh sh saying rajes take a backup of a existing Docker file quickly hit enter hit enter
# right yes by right now do V now do one thing now do not VI do greater than symbol SP Docker file this will remove the contents of the file without deleting the file okay guys this will nullify the file nullify means this will delete the contents of the file without deleting the file Docker file is one name with the D capital and a Docker and the file together enter now do write VI Docker file enter copy paste the one which I have put in the chat window
# yeah control a control C control V that is also taking time for us now you see anit shpa with Focus here the first argument you see what it is argument
# okay what it is argument
# oh yeah
# she copy is not proper you have not even just a yeah not copied the things proper hash you're saying before hash now from the docker file starts from a from the first instruction from to everyone delete everything else in the file
# yeah
# oh my God like this you can't delete this put right es press escape and just press Double D keep going like that until everything is [Music] deleted guys today I'm there tell you the commands tomorrow in the interview no one will be there you think about yourselves situations what is the problem rajeswar here in the copy copy the thing in the notepad from the world which is written from Alpine colon 3.9.3 copy the thing there do until CMD cat. text copy the things in the notepad first me see if you're copying it correctly or not great now right now here you see in the maintainer if you guys want you can replace it with your name it is a author name
# okay Shilpa and other guys here I have given argument one as a welcome user collab NEX you can give other welcome user also and what you are doing you're writing a command that is cat message.
# text means this instructions right the cat me this instruction which is printed here right welcome an argument name welcome user to the docker world this will go to this and once you create a container or run a container it will print you the message save this file
# okay run this command to build guys Escape col WQ save run that command copy paste now we had defined already a Docker default option here right after argument colon B1 just press dot just write dot Docker file it has to now we have created an image here right now run this command which will run the container we have created an image with the argument name as a image and V1 is what my version of a image now this time I'm running the image with a default options okay with a default argument on so it gave me a default username that is welcome user
# what uh to welcome collab to the docker word because default was that now let's say that how we can run with that so when you have copy paste a command when you have to run the image where you have to pass the welcome user argument name or you have to give the value to that you have to give minus minus build minus argument what you have to give minus minus build argument so you see in the command it is written right copy paste that now run the image again and this time you see I have created a version two of the images AR colon V2
# this is how you work in the real time just write Docker run ARG AR colon V2 it is run run right now you see it gave me welcome suchin why because I have given the build argument came different this is how you can build the images with your own arguments this is how you can run the images with your own argument and with the different versions getting my point
# yes
# yes likewise we have a different set of varieties and you know mechanisms and a place through which you can talk
# and you can work upon accordingly I'll share you the different formats of a Docker file
# but again you have to go through more big big Docker files and stuff you have to write you have to see that different instruction which we pass like from run copy add and all those things and this is how this works there are the things which creates a layer there are things which doesn't everything is in a document which will be shared with you so that you understand how the docker file is written and how it is created with a different different ways and I'll sh few GitHub links which will give you other things also getting it
# yeah so far any questions now in the next class that is tomorrow the class will be only of 1 hour
# okay
# and I'm preponing a Class 1 hour before as I have to go somewhere at around 3:00
# so we'll be having a 2 to 3 only so 2: p.m.
# I actually tomorrow class okay just for tomorrow so fine with you guys right
# yeah now we will be doing what that we will be creating a private Docker registry tomorrow we'll talk about a Docker networking and Docker volumes the other three important things we'll talk about that how we can create a private Docker registry
# okay
# right now whatever the docker registry mean Docker Hub W part which we did yesterday in last class that was my public registry which was open to everyone probably right by default private we will create so that it will be exposed to us only no one else can see it
# okay like you do in the corporates then we talk about Docker volume and then we'll talk about Docker networking and if I forget just remind me that how can I talk about the ECR that is elastic container registry which is in AWS
# okay
# y
# yeah will finish my okay Docker completely tomorrow we talked about so far that how we can we started with creating a dockerhub account we started with running a container running the images how you can work with the images create the images save the images how you can uh push it to the Hub then we move to the containers we talked about how we can run the containers what's the difference between the few commands of the containers how we can inspect the images and the containers can get the other attributes how we can access the container shell or go inside the container how we can run the commands and all those things and these things and then we talked about the docker file today we talked about the you know the uh we're going to talk about Docker volume Docker networking and private Docker registry these are the few components which are very very important for the docker to start with and to understander
# so how are guys how was session apart from my shouting any other thing I really find it very bad that when you guys don't work with the commands properly especially rajeswar for you this is something you have to very
# yeah I need to go through the commands again have to otherwise very difficult for you
# hello
# okay how was the session anit and something
# new
# yeah
# yeah
# I it was very good session
# I learned so many like Docker file commands which we used to run like run command entry point and label all these things actually I did one spring boot on this only Docker file so with with that also like I learned three to four commands how to create our owning boot image
# great Shila I think you are joining first class of today's do so you are able to cope up get it
# yeah
# yeah
# I have gone through previous recorded sessions I am uh yeah getting it
# but
# yeah I need to go through it uh one or two times more again
# okay thank you
# but any questions from you
# yes it is new for me I have to go to yeah more and more practice will help us to do this I'll share you guys the assignment and other things also everything for this I have a very good notes please like this I'm quite occupied with some of you know
# office
# but I'll share with you guys
# okay
# anyway
# so I think we are good with the things
# okay let's meet up again tomorrow same time same sorry 2 p.m. IST and uh let's wrap up Docker
# and then we'll talk about further things
# okay thank you
# yeah
# okay
# thanks guys

# %% [markdown]
# ### Task 5: Get all Tokens from Document

# %%
tokens = [token.text for token in document]
tokens
# Out:
# [' ',
#  'if',
#  'I',
#  'have',
#  'to',
#  'share',
#  'or',
#  'if',
#  'I',
#  'have',
#  'to',
#  'do',
#  'any',
#  'kind',
#  'of',
#  'you',
#  'know',
#  'the',
#  'image',
#  'of',
#  'something',
#  'so',
#  'how',
#  'can',
#  'I',
#  'save',
#  'it',
#  'any',
#  'idea',
#  'so',
#  'far',
#  'we',
#  'talked',
#  'about',
#  'doer',
#  'Hub',
#  'we',
#  'talked',
#  'about',
#  'how',
#  'to',
#  'run',
#  'a',
#  'container',
#  'how',
#  'to',
#  'do',
#  'the',
#  'image',
#  'and',
#  'all',
#  'those',
#  'parts',
#  'and',
#  'things',
#  'now',
#  'my',
#  'question',
#  'is',
#  'if',
#  'I',
#  'have',
#  'to',
#  'talk',
#  'about',
#  'the',
#  'that',
#  'we',
#  'also',
#  'talked',
#  'about',
#  'that',
#  'how',
#  'we',
#  'can',
#  'build',
#  'a',
#  'image',
#  'and',
#  'push',
#  'it',
#  'to',
#  'the',
#  'docker',
#  'Hub',
#  'uh',
#  'now',
#  'my',
#  'question',
#  'is',
#  'that',
#  'if',
#  'I',
#  'have',
#  'to',
#  'talk',
#  'about',
#  'that',
#  'how',
#  'can',
#  'we',
#  'save',
#  'the',
#  'image',
#  'and',
#  'the',
#  'container',
#  'as',
#  'a',
#  'tire',
#  'file',
#  'or',
#  'something',
#  'we',
#  'talked',
#  'about',
#  'this',
#  'right',
#  'yeah',
#  'we',
#  'can',
#  'save',
#  'it',
#  'how',
#  'you',
#  'told',
#  'with',
#  'the',
#  'command',
#  'uh',
#  'like',
#  'Docker',
#  'save',
#  'with',
#  'this',
#  'we',
#  'can',
#  'save',
#  'our',
#  'image',
#  'as',
#  'a',
#  't',
#  'file',
#  'yeah',
#  'Docker',
#  'export',
#  'Docker',
#  'save',
#  'command',
#  'okay',
#  'yeah',
#  'those',
#  'are',
#  'the',
#  'two',
#  'command',
#  'through',
#  'which',
#  'we',
#  'can',
#  'do',
#  'this',
#  'now',
#  'today',
#  'we',
#  'are',
#  'going',
#  'to',
#  'talk',
#  'about',
#  'the',
#  'docker',
#  'file',
#  'okay',
#  'guys',
#  'what',
#  'is',
#  'Docker',
#  'file',
#  'and',
#  'how',
#  'does',
#  'it',
#  'work',
#  'in',
#  'these',
#  'things',
#  'right',
#  'the',
#  'docker',
#  'file',
#  'is',
#  'nothing',
#  'it',
#  "'s",
#  'a',
#  'text',
#  'file',
#  'you',
#  'know',
#  'which',
#  'contains',
#  'like',
#  'whatever',
#  'now',
#  'the',
#  'operations',
#  'you',
#  'have',
#  'performed',
#  'all',
#  'those',
#  'operations',
#  'you',
#  'are',
#  'putting',
#  'up',
#  'in',
#  'a',
#  'text',
#  'file',
#  'and',
#  'jotting',
#  'down',
#  'it',
#  'together',
#  'okay',
#  'that',
#  'is',
#  'your',
#  'Docker',
#  'file',
#  'okay',
#  'now',
#  'those',
#  'instructions',
#  'are',
#  'nothing',
#  'you',
#  'know',
#  'it',
#  'is',
#  'basically',
#  'you',
#  'execute',
#  'those',
#  'instructions',
#  'you',
#  'write',
#  'in',
#  'the',
#  'particular',
#  'order',
#  'and',
#  'that',
#  'is',
#  'how',
#  'it',
#  'is',
#  'written',
#  'and',
#  'it',
#  'creates',
#  'the',
#  'images',
#  'and',
#  'these',
#  'things',
#  'now',
#  'let',
#  "'s",
#  'say',
#  'that',
#  'if',
#  'we',
#  'have',
#  'to',
#  'create',
#  'a',
#  'image',
#  'where',
#  'you',
#  'have',
#  'to',
#  'install',
#  'a',
#  'git',
#  'right',
#  'what',
#  'you',
#  'do',
#  'you',
#  'write',
#  'Docker',
#  'build',
#  'G',
#  'or',
#  'Docker',
#  'image',
#  'git',
#  'you',
#  'will',
#  'pull',
#  'and',
#  'then',
#  'run',
#  'the',
#  'container',
#  'correct',
#  'correct',
#  'yeah',
#  'yeah',
#  'now',
#  'what',
#  'in',
#  'our',
#  'case',
#  'what',
#  'I',
#  "'m",
#  'am',
#  'going',
#  'to',
#  'do',
#  'is',
#  'that',
#  'I',
#  'have',
#  'to',
#  'run',
#  'or',
#  'I',
#  'have',
#  'to',
#  'install',
#  'the',
#  'git',
#  'so',
#  'for',
#  'that',
#  'let',
#  "'s",
#  'say',
#  'I',
#  'will',
#  'install',
#  'a',
#  'operating',
#  'system',
#  'name',
#  'as',
#  'Alpine',
#  'what',
#  'I',
#  "'ll",
#  'do',
#  'I',
#  "'ll",
#  'install',
#  'the',
#  'operating',
#  'system',
#  'Alpine',
#  'and',
#  'I',
#  'will',
#  'write',
#  'that',
#  'okay',
#  'how',
#  'can',
#  'I',
#  'install',
#  'the',
#  'git',
#  'now',
#  'you',
#  'see',
#  'this',
#  'is',
#  'a',
#  'example',
#  'of',
#  'a',
#  'Docker',
#  'file',
#  'okay',
#  'I',
#  'will',
#  'write',
#  'Run',
#  'apk',
#  'update',
#  'and',
#  'Run',
#  'apk',
#  'G',
#  'Now',
#  'APK',
#  'add',
#  'G',
#  'APK',
#  'update',
#  'are',
#  'what',
#  'those',
#  'are',
#  'the',
#  'two',
#  'commands',
#  'for',
#  'operating',
#  'system',
#  'Alpine',
#  'okay',
#  'now',
#  'you',
#  'can',
#  'change',
#  'it',
#  'based',
#  'on',
#  'the',
#  'ubu',
#  'based',
#  'on',
#  'any',
#  'other',
#  'thing',
#  'correct',
#  'yeah',
#  'now',
#  'once',
#  'it',
#  'is',
#  'done',
#  'then',
#  'we',
#  'can',
#  'do',
#  'what',
#  'we',
#  'can',
#  'build',
#  'this',
#  'image',
#  'how',
#  'we',
#  'can',
#  'build',
#  'using',
#  'a',
#  'Docker',
#  'build',
#  'command',
#  'and',
#  'we',
#  'can',
#  'further',
#  'tag',
#  'the',
#  'image',
#  'where',
#  'the',
#  'things',
#  'are',
#  'there',
#  'now',
#  'once',
#  'this',
#  'is',
#  'done',
#  'we',
#  'can',
#  'create',
#  'a',
#  'container',
#  'and',
#  'do',
#  'the',
#  'things',
#  'this',
#  'will',
#  'help',
#  'me',
#  'to',
#  'do',
#  'all',
#  'the',
#  'things',
#  'now',
#  'the',
#  'point',
#  'is',
#  'how',
#  'can',
#  'we',
#  'build',
#  'a',
#  'image',
#  'how',
#  'can',
#  'we',
#  'do',
#  'all',
#  'the',
#  'steps',
#  'so',
#  'create',
#  'a',
#  'Docker',
#  'file',
#  'go',
#  'to',
#  'the',
#  'server',
#  'or',
#  'wherever',
#  'Docker',
#  'is',
#  'installed',
#  'go',
#  '[',
#  'Music',
#  ']',
#  'there',
#  'do',
#  'like',
#  'I',
#  'have',
#  'done',
#  'through',
#  'AWS',
#  'awss',
#  '[',
#  'Music',
#  ']',
#  'okay',
#  'yeah',
#  'right',
#  'do',
#  'minus',
#  'minus',
#  'version',
#  'enter',
#  'okay',
#  'uh',
#  'do',
#  'do',
#  'PWD',
#  'go',
#  'to',
#  'any',
#  'home',
#  'directory',
#  'right',
#  'CD',
#  'hyphen',
#  'hyphen',
#  'just',
#  'write',
#  'hyy',
#  'C',
#  'Hy',
#  'CD',
#  'space',
#  'Hy',
#  'enter',
#  'okay',
#  'so',
#  'okay',
#  'that',
#  'is',
#  'let',
#  'just',
#  'do',
#  'CD',
#  'and',
#  'enter',
#  'okay',
#  'home',
#  'directory',
#  'that',
#  'on',
#  'fine',
#  'no',
#  'problem',
#  'now',
#  'here',
#  'write',
#  'VI',
#  'Docker',
#  'file',
#  'in',
#  'capital',
#  'Docker',
#  'file',
#  'scho',
#  'I',
#  'write',
#  'down',
#  'the',
#  'paste',
#  'down',
#  'the',
#  'those',
#  'three',
#  'commands',
#  'which',
#  'I',
#  'have',
#  'done',
#  'sent',
#  '[',
#  'Music',
#  ']',
#  'over',
#  'I',
#  'did',
#  "n't",
#  'get',
#  'you',
#  'what',
#  'you',
#  'said',
#  'in',
#  'the',
#  'chat',
#  'window',
#  'the',
#  'content',
#  'of',
#  'a',
#  'Docker',
#  'file',
#  'right',
#  'okay',
#  'um',
#  'listen',
#  'from',
#  'Alpine',
#  'yeah',
#  'okay',
#  'P',
#  'there',
#  'and',
#  'then',
#  'hold',
#  'on',
#  'I',
#  "'ll",
#  'tell',
#  'you',
#  'what',
#  'now',
#  'with',
#  'this',
#  'there',
#  'is',
#  'one',
#  'question',
#  'in',
#  'the',
#  'interview',
#  'which',
#  'is',
#  'asked',
#  'most',
#  'of',
#  'the',
#  'time',
#  'that',
#  'what',
#  'are',
#  'the',
#  'default',
#  'parameters',
#  'or',
#  'the',
#  'attributes',
#  'or',
#  'you',
#  'know',
#  'the',
#  'instruction',
#  'which',
#  'you',
#  'have',
#  'to',
#  'pass',
#  'when',
#  'you',
#  'write',
#  'a',
#  'dogger',
#  'file',
#  'now',
#  'from',
#  'is',
#  'what',
#  'from',
#  'will',
#  'tell',
#  'you',
#  'that',
#  'which',
#  'image',
#  'has',
#  'to',
#  'be',
#  'used',
#  'okay',
#  'Alpine',
#  'colum',
#  '3.5',
#  'is',
#  'what',
#  'this',
#  'a',
#  'image',
#  'of',
#  'Alpine',
#  'OS',
#  'with',
#  'version',
#  '3.5',
#  'run',
#  'is',
#  'a',
#  'command',
#  'to',
#  'run',
#  'the',
#  'com',
#  'this',
#  'any',
#  'commands',
#  'and',
#  'anything',
#  'right',
#  'that',
#  'is',
#  'one',
#  'instruction',
#  'so',
#  'from',
#  'run',
#  'all',
#  'these',
#  'are',
#  'keywords',
#  'here',
#  'okay',
#  'these',
#  'are',
#  'the',
#  'instruction',
#  'we',
#  "'ll",
#  'see',
#  'further',
#  'more',
#  'as',
#  'and',
#  'then',
#  'we',
#  'will',
#  'move',
#  'likewise',
#  'we',
#  'have',
#  'one',
#  'instruction',
#  'by',
#  'which',
#  'is',
#  'known',
#  'as',
#  'maintainer',
#  'what',
#  'it',
#  'is',
#  'known',
#  'as',
#  'maintainer',
#  'maintainer',
#  'those',
#  'keywords',
#  'should',
#  'be',
#  'in',
#  'a',
#  'capital',
#  'or',
#  'anything',
#  'huh',
#  'those',
#  'keywords',
#  'run',
#  'Capital',
#  'all',
#  'capital',
#  'maintainer',
#  'is',
#  'also',
#  'something',
#  'which',
#  'is',
#  'the',
#  'author',
#  'okay',
#  'after',
#  'maintainer',
#  'you',
#  'can',
#  'give',
#  'author',
#  'which',
#  'will',
#  'tell',
#  'you',
#  'that',
#  'maintains',
#  'this',
#  'file',
#  'so',
#  'likewise',
#  'you',
#  'have',
#  'different',
#  'other',
#  'parameters',
#  'which',
#  'we',
#  'will',
#  'talk',
#  'about',
#  'okay',
#  'now',
#  'save',
#  'this',
#  'file',
#  'okay',
#  'now',
#  'Escape',
#  'colon',
#  '[',
#  'Music',
#  ']',
#  'WQ',
#  'see',
#  'last',
#  'class',
#  'only',
#  'you',
#  'guys',
#  'got',
#  'a',
#  'good',
#  'one',
#  'from',
#  'like',
#  'not',
#  'like',
#  'any',
#  'kind',
#  'of',
#  'a',
#  'scolding',
#  'or',
#  'something',
#  'but',
#  'I',
#  'was',
#  'telling',
#  'you',
#  'guys',
#  'last',
#  'class',
#  'also',
#  'that',
#  'you',
#  'guys',
#  'are',
#  'so',
#  'weak',
#  'in',
#  'Linux',
#  'so',
#  'far',
#  'but',
#  'still',
#  'you',
#  'guys',
#  'are',
#  'in',
#  'the',
#  'same',
#  'condition',
#  'one',
#  'week',
#  'gone',
#  'no',
#  'progress',
#  'this',
#  'show',
#  'that',
#  'no',
#  'study',
#  'done',
#  'Escape',
#  'press',
#  'Escape',
#  'now',
#  'press',
#  'colon',
#  'WQ',
#  'lbo',
#  'W',
#  'WQ',
#  'enter',
#  'if',
#  'this',
#  'would',
#  'be',
#  'the',
#  'situation',
#  'I',
#  "'m",
#  'telling',
#  'you',
#  'guys',
#  'to',
#  'be',
#  'honest',
#  'you',
#  'have',
#  'to',
#  'make',
#  'your',
#  'limits',
#  'very',
#  'strong',
#  'if',
#  'you',
#  'do',
#  "n't",
#  'have',
#  'your',
#  'Linux',
#  'strongs',
#  'any',
#  'interview',
#  'go',
#  'for',
#  'DeVos',
#  'interview',
#  'you',
#  'go',
#  'for',
#  'a',
#  'CO',
#  'interview',
#  'Linux',
#  'Linux',
#  'Basics',
#  'are',
#  'very',
#  'important',
#  'these',
#  'are',
#  'are',
#  'Basics',
#  '[',
#  'Music',
#  ']',
#  'actually',
#  'anyways',
#  'write',
#  'a',
#  'command',
#  'Docker',
#  'space',
#  'build',
#  'space',
#  'minus',
#  't',
#  'space',
#  'now',
#  'give',
#  'your',
#  'dockerhub',
#  'username',
#  'here',
#  'email',
#  'ID',
#  'that',
#  "'s",
#  'okay',
#  ...]

# %% [markdown]
# ### Task 6: Calculate Frequency of Tokens

# %%
word_frequencies = {}
for word in document:
    text = word.text.lower()
    if text not in list(STOP_WORDS) and text not in punctuation:
        if word.text not in word_frequencies.keys():
            word_frequencies[word.text] = 1
        else:
            word_frequencies[word.text] += 1
word_frequencies
# Out:
# {' ': 1,
#  'share': 9,
#  'kind': 2,
#  'know': 9,
#  'image': 68,
#  'save': 13,
#  'idea': 1,
#  'far': 9,
#  'talked': 8,
#  'doer': 3,
#  'Hub': 4,
#  'run': 64,
#  'container': 19,
#  'parts': 3,
#  'things': 27,
#  'question': 5,
#  'talk': 13,
#  'build': 22,
#  'push': 2,
#  'docker': 21,
#  'uh': 16,
#  'tire': 1,
#  'file': 81,
#  'right': 61,
#  'yeah': 57,
#  'told': 1,
#  'command': 64,
#  'like': 26,
#  'Docker': 81,
#  't': 6,
#  'export': 1,
#  'okay': 68,
#  'today': 5,
#  'going': 6,
#  'guys': 24,
#  'work': 16,
#  'text': 6,
#  'contains': 1,
#  'operations': 2,
#  'performed': 1,
#  'putting': 1,
#  'jotting': 1,
#  'instructions': 7,
#  'basically': 5,
#  'execute': 2,
#  'write': 28,
#  'particular': 1,
#  'order': 1,
#  'written': 5,
#  'creates': 5,
#  'images': 14,
#  'let': 15,
#  'create': 27,
#  'install': 6,
#  'git': 5,
#  'G': 5,
#  'pull': 1,
#  'correct': 7,
#  'case': 3,
#  'operating': 4,
#  'system': 3,
#  'Alpine': 9,
#  'example': 10,
#  'Run': 3,
#  'apk': 2,
#  'update': 2,
#  'APK': 2,
#  'add': 10,
#  'commands': 14,
#  'change': 5,
#  'based': 2,
#  'ubu': 1,
#  'thing': 9,
#  'tag': 1,
#  'help': 6,
#  'point': 11,
#  'steps': 1,
#  'server': 2,
#  'installed': 3,
#  'Music': 31,
#  'AWS': 2,
#  'awss': 1,
#  'minus': 15,
#  'version': 4,
#  'enter': 16,
#  'PWD': 1,
#  'home': 2,
#  'directory': 8,
#  'CD': 3,
#  'hyphen': 3,
#  'hyy': 1,
#  'C': 2,
#  'Hy': 2,
#  'space': 15,
#  'fine': 2,
#  'problem': 7,
#  'VI': 4,
#  'capital': 8,
#  'scho': 1,
#  'paste': 9,
#  'sent': 1,
#  'said': 3,
#  'chat': 3,
#  'window': 3,
#  'content': 2,
#  'um': 1,
#  'listen': 1,
#  'P': 3,
#  'hold': 6,
#  'tell': 9,
#  'interview': 5,
#  'asked': 2,
#  'time': 9,
#  'default': 8,
#  'parameters': 2,
#  'attributes': 2,
#  'instruction': 20,
#  'pass': 5,
#  'dogger': 1,
#  'colum': 1,
#  '3.5': 2,
#  'OS': 1,
#  'com': 1,
#  'keywords': 6,
#  'likewise': 4,
#  'known': 3,
#  'maintainer': 7,
#  'huh': 4,
#  'Capital': 1,
#  'author': 3,
#  'maintains': 1,
#  'different': 11,
#  'Escape': 4,
#  'colon': 7,
#  'WQ': 5,
#  'class': 8,
#  'got': 4,
#  'good': 7,
#  'scolding': 1,
#  'telling': 2,
#  'weak': 1,
#  'Linux': 6,
#  'condition': 1,
#  'week': 1,
#  'gone': 2,
#  'progress': 1,
#  'study': 1,
#  'press': 6,
#  'lbo': 1,
#  'W': 3,
#  'situation': 1,
#  'honest': 1,
#  'limits': 1,
#  'strong': 1,
#  'strongs': 1,
#  'DeVos': 1,
#  'CO': 1,
#  'Basics': 2,
#  'important': 5,
#  'actually': 4,
#  'anyways': 2,
#  'dockerhub': 3,
#  'username': 2,
#  'email': 1,
#  'ID': 13,
#  'rajeswar': 5,
#  'SL': 3,
#  'WR': 3,
#  'hyen': 2,
#  'gate': 1,
#  'dot': 4,
#  'LS': 3,
#  'rename': 4,
#  'D': 6,
#  'rajes': 4,
#  'mind': 2,
#  'words': 1,
#  'care': 2,
#  'high': 1,
#  'course': 2,
#  'months': 1,
#  'aware': 1,
#  'end': 1,
#  'Shila': 3,
#  'sha': 1,
#  'speaking': 2,
#  'mute': 2,
#  'anit': 7,
#  'MV': 2,
#  'sorry': 6,
#  'changed': 2,
#  'new': 15,
#  'list': 1,
#  'AR': 3,
#  'type': 1,
#  'hit': 3,
#  'syntax': 2,
#  'wrong': 2,
#  'gave': 4,
#  'error': 8,
#  'maximize': 1,
#  'screen': 4,
#  'layers': 11,
#  'created': 17,
#  'pulled': 1,
#  'updated': 1,
#  'package': 1,
#  'giving': 4,
#  'response': 2,
#  'demon': 2,
#  'running': 10,
#  'service': 1,
#  'status': 1,
#  'check': 6,
#  'rajeswari': 3,
#  'built': 2,
#  'SE': 1,
#  'dotop': 1,
#  'minute': 2,
#  'Imes': 1,
#  'imagees': 1,
#  'ago': 1,
#  'ran': 2,
#  'successfully': 1,
#  'yes': 7,
#  'playing': 1,
#  'bit': 1,
#  'able': 2,
#  'start': 2,
#  'containers': 6,
#  'execut': 1,
#  'sh': 5,
#  'inside': 2,
#  'understand': 2,
#  'layering': 1,
#  'concept': 1,
#  'runnable': 1,
#  'instance': 2,
#  'runable': 1,
#  'parent': 1,
#  'read': 4,
#  'means': 6,
#  'layer': 24,
#  'execution': 1,
#  'added': 1,
#  'copy': 20,
#  'adds': 2,
#  'additional': 1,
#  'mainly': 1,
#  'getting': 13,
#  'creating': 7,
#  'm': 1,
#  'called': 2,
#  'separate': 1,
#  'path': 2,
#  'parameter': 2,
#  '5': 1,
#  'think': 6,
#  'saying': 4,
#  'Shar': 1,
#  'backup': 7,
#  'earlier': 1,
#  'shared': 2,
#  'bku': 1,
#  'improve': 2,
#  'skill': 1,
#  'sets': 1,
#  'forget': 3,
#  'blunt': 1,
#  'feel': 1,
#  'bad': 2,
#  'away': 1,
#  'bitter': 1,
#  'truth': 1,
#  'skills': 1,
#  'contents': 3,
#  'apart': 2,
#  'explain': 1,
#  'questions': 4,
#  'completely': 2,
#  'shows': 1,
#  'con': 1,
#  'Focus': 2,
#  'sake': 1,
#  'cloud': 2,
#  'escape': 2,
#  'ahead': 1,
#  'B': 3,
#  'whichever': 1,
#  'generates': 2,
#  'unique': 1,
#  'step': 2,
#  'generated': 1,
#  'complete': 2,
#  'want': 4,
#  'look': 2,
#  'helpful': 1,
#  'history': 6,
#  '23': 1,
#  'doger': 1,
#  'blank': 1,
#  'ER': 2,
#  'option': 3,
#  'demo': 1,
#  'word': 2,
#  'repository': 2,
#  'K': 2,
#  'contact': 2,
#  'account': 2,
#  'instead': 5,
#  'wet': 1,
#  'h': 3,
#  'lower': 1,
#  'letter': 1,
#  'required': 1,
#  'H': 2,
#  'andila': 1,
#  'wo': 2,
#  'works': 2,
#  'files': 2,
#  'maybe': 1,
#  'need': 3,
#  'working': 4,
#  'worked': 1,
#  'difference': 2,
#  'keyword': 3,
#  'defining': 1,
#  'continuously': 1,
#  'pointing': 1,
#  'invalid': 2,
#  'argument': 17,
#  'cled': 1,
#  'use': 4,
#  '1': 4,
#  '2': 6,
#  '3': 3,
#  'Raj': 1,
#  'took': 1,
#  'saw': 4,
#  'seeing': 1,
#  'sweet': 1,
#  'thank': 3,
#  'hist': 1,
#  'spelling': 2,
#  'History': 1,
#  'sir': 1,
#  'alpide': 1,
#  'identify': 1,
#  'visualize': 3,
#  'asking': 3,
#  'V': 4,
#  '123': 1,
#  'cre': 1,
#  'slash': 1,
#  'hyph': 1,
#  'given': 4,
#  'test': 5,
#  'hello': 5,
#  'happened': 2,
#  'touch': 4,
#  'man': 2,
#  'Tex': 1,
#  'simple': 1,
#  'o': 1,
#  'u': 1,
#  'c': 1,
#  'TC': 1,
#  'T': 1,
#  'Test': 1,
#  'viralized': 1,
#  'replace': 2,
#  'second': 1,
#  'waiting': 2,
#  'Mr': 1,
#  's': 1,
#  'doy': 1,
#  'RM': 1,
#  'visualiz': 1,
#  'remove': 3,
#  'Explorer': 1,
#  'opens': 1,
#  'rmus': 1,
#  'mapping': 1,
#  'volume': 4,
#  'visualization': 1,
#  'link': 1,
#  'CMD': 3,
#  'brackets': 2,
#  'entry': 6,
#  'di': 3,
#  'current': 1,
#  'specified': 1,
#  'root': 1,
#  'mean': 2,
#  'Applause': 1,
#  'says': 3,
#  'bin': 1,
#  'Eco': 4,
#  'cont': 1,
#  'label': 2,
#  'tells': 1,
#  'comfort': 1,
#  'laptop': 1,
#  'currently': 1,
#  'electricity': 1,
#  'hours': 1,
#  'joined': 1,
#  'Mobile': 1,
#  'Sila': 1,
#  'sain': 1,
#  'login': 1,
#  'rajar': 1,
#  'coming': 1,
#  'writing': 2,
#  'doctor': 1,
#  'lot': 1,
#  'examples': 1,
#  'previous': 3,
#  "ma'am": 1,
#  'F': 1,
#  'properly': 2,
#  'WoW': 1,
#  'renaming': 1,
#  'Mo': 1,
#  'hey': 1,
#  'waste': 1,
#  'repace': 1,
#  'Command': 1,
#  'verify': 1,
#  'soon': 1,
#  'passed': 1,
#  'executes': 2,
#  'hash': 3,
#  'Echo': 1,
#  'remember': 1,
#  'result': 1,
#  'quickly': 2,
#  'present': 1,
#  'TI': 1,
#  'metadata': 1,
#  'information': 2,
#  'Okay': 1,
#  'sear': 1,
#  'document': 2,
#  'worry': 2,
#  'instru': 1,
#  'runs': 1,
#  'directly': 1,
#  'multiple': 1,
#  'happen': 1,
#  'user': 7,
#  'messages': 1,
#  'existing': 1,
#  'greater': 1,
#  'symbol': 1,
#  'SP': 1,
#  'deleting': 2,
#  'nullify': 2,
#  'delete': 3,
#  'control': 3,
#  'taking': 1,
#  'shpa': 1,
#  'oh': 2,
#  'proper': 2,
#  'copied': 1,
#  'starts': 1,
#  'God': 1,
#  'es': 1,
#  'Double': 1,
#  'deleted': 1,
#  'tomorrow': 7,
#  'situations': 1,
#  'notepad': 2,
#  'world': 2,
#  '3.9.3': 1,
#  'cat': 3,
#  'copying': 1,
#  'correctly': 1,
#  'great': 2,
#  'Shilpa': 1,
#  'welcome': 8,
#  'collab': 2,
#  'NEX': 1,
#  'message': 2,
#  'printed': 1,
#  'print': 1,
#  'col': 1,
#  'defined': 1,
#  'B1': 1,
#  'V1': 1,
#  'options': 1,
#  'value': 1,
#  'V2': 2,
#  'real': 1,
#  'ARG': 1,
#  'suchin': 1,
#  'came': 1,
#  'arguments': 1,
#  'versions': 1,
#  'set': 1,
#  'varieties': 1,
#  'mechanisms': 1,
#  'place': 1,
#  'accordingly': 1,
#  'formats': 1,
#  'big': 2,
#  'stuff': 1,
#  'ways': 1,
#  'GitHub': 1,
#  'links': 1,
#  'hour': 2,
#  'preponing': 1,
#  'Class': 1,
#  '3:00': 1,
#  'having': 1,
#  'p.m.': 2,
#  'private': 4,
#  'registry': 6,
#  'networking': 3,
#  'volumes': 1,
#  'yesterday': 1,
#  'public': 1,
#  'open': 1,
#  'probably': 1,
#  'exposed': 1,
#  'corporates': 1,
#  'remind': 1,
#  'ECR': 1,
#  'elastic': 1,
#  'y': 1,
#  'finish': 1,
#  'started': 2,
#  'inspect': 1,
#  'access': 1,
#  'shell': 1,
#  'components': 1,
#  'understander': 1,
#  'session': 3,
#  'shouting': 1,
#  'find': 1,
#  'especially': 1,
#  'difficult': 1,
#  'learned': 2,
#  'spring': 1,
#  'boot': 2,
#  'owning': 1,
#  'joining': 1,
#  'cope': 1,
#  'recorded': 1,
#  'sessions': 1,
#  'times': 1,
#  'practice': 1,
#  'assignment': 1,
#  'notes': 1,
#  'occupied': 1,
#  'office': 1,
#  'meet': 1,
#  'IST': 1,
#  'wrap': 1,
#  'thanks': 1}

# %% [markdown]
# ### Task 7: Normalize the Frequency of Tokens

# %%
max_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency
word_frequencies
# Out:
# {' ': 0.012345679012345678,
#  'share': 0.1111111111111111,
#  'kind': 0.024691358024691357,
#  'know': 0.1111111111111111,
#  'image': 0.8395061728395061,
#  'save': 0.16049382716049382,
#  'idea': 0.012345679012345678,
#  'far': 0.1111111111111111,
#  'talked': 0.09876543209876543,
#  'doer': 0.037037037037037035,
#  'Hub': 0.04938271604938271,
#  'run': 0.7901234567901234,
#  'container': 0.2345679012345679,
#  'parts': 0.037037037037037035,
#  'things': 0.3333333333333333,
#  'question': 0.06172839506172839,
#  'talk': 0.16049382716049382,
#  'build': 0.2716049382716049,
#  'push': 0.024691358024691357,
#  'docker': 0.25925925925925924,
#  'uh': 0.19753086419753085,
#  'tire': 0.012345679012345678,
#  'file': 1.0,
#  'right': 0.7530864197530864,
#  'yeah': 0.7037037037037037,
#  'told': 0.012345679012345678,
#  'command': 0.7901234567901234,
#  'like': 0.32098765432098764,
#  'Docker': 1.0,
#  't': 0.07407407407407407,
#  'export': 0.012345679012345678,
#  'okay': 0.8395061728395061,
#  'today': 0.06172839506172839,
#  'going': 0.07407407407407407,
#  'guys': 0.2962962962962963,
#  'work': 0.19753086419753085,
#  'text': 0.07407407407407407,
#  'contains': 0.012345679012345678,
#  'operations': 0.024691358024691357,
#  'performed': 0.012345679012345678,
#  'putting': 0.012345679012345678,
#  'jotting': 0.012345679012345678,
#  'instructions': 0.08641975308641975,
#  'basically': 0.06172839506172839,
#  'execute': 0.024691358024691357,
#  'write': 0.345679012345679,
#  'particular': 0.012345679012345678,
#  'order': 0.012345679012345678,
#  'written': 0.06172839506172839,
#  'creates': 0.06172839506172839,
#  'images': 0.1728395061728395,
#  'let': 0.18518518518518517,
#  'create': 0.3333333333333333,
#  'install': 0.07407407407407407,
#  'git': 0.06172839506172839,
#  'G': 0.06172839506172839,
#  'pull': 0.012345679012345678,
#  'correct': 0.08641975308641975,
#  'case': 0.037037037037037035,
#  'operating': 0.04938271604938271,
#  'system': 0.037037037037037035,
#  'Alpine': 0.1111111111111111,
#  'example': 0.12345679012345678,
#  'Run': 0.037037037037037035,
#  'apk': 0.024691358024691357,
#  'update': 0.024691358024691357,
#  'APK': 0.024691358024691357,
#  'add': 0.12345679012345678,
#  'commands': 0.1728395061728395,
#  'change': 0.06172839506172839,
#  'based': 0.024691358024691357,
#  'ubu': 0.012345679012345678,
#  'thing': 0.1111111111111111,
#  'tag': 0.012345679012345678,
#  'help': 0.07407407407407407,
#  'point': 0.13580246913580246,
#  'steps': 0.012345679012345678,
#  'server': 0.024691358024691357,
#  'installed': 0.037037037037037035,
#  'Music': 0.38271604938271603,
#  'AWS': 0.024691358024691357,
#  'awss': 0.012345679012345678,
#  'minus': 0.18518518518518517,
#  'version': 0.04938271604938271,
#  'enter': 0.19753086419753085,
#  'PWD': 0.012345679012345678,
#  'home': 0.024691358024691357,
#  'directory': 0.09876543209876543,
#  'CD': 0.037037037037037035,
#  'hyphen': 0.037037037037037035,
#  'hyy': 0.012345679012345678,
#  'C': 0.024691358024691357,
#  'Hy': 0.024691358024691357,
#  'space': 0.18518518518518517,
#  'fine': 0.024691358024691357,
#  'problem': 0.08641975308641975,
#  'VI': 0.04938271604938271,
#  'capital': 0.09876543209876543,
#  'scho': 0.012345679012345678,
#  'paste': 0.1111111111111111,
#  'sent': 0.012345679012345678,
#  'said': 0.037037037037037035,
#  'chat': 0.037037037037037035,
#  'window': 0.037037037037037035,
#  'content': 0.024691358024691357,
#  'um': 0.012345679012345678,
#  'listen': 0.012345679012345678,
#  'P': 0.037037037037037035,
#  'hold': 0.07407407407407407,
#  'tell': 0.1111111111111111,
#  'interview': 0.06172839506172839,
#  'asked': 0.024691358024691357,
#  'time': 0.1111111111111111,
#  'default': 0.09876543209876543,
#  'parameters': 0.024691358024691357,
#  'attributes': 0.024691358024691357,
#  'instruction': 0.24691358024691357,
#  'pass': 0.06172839506172839,
#  'dogger': 0.012345679012345678,
#  'colum': 0.012345679012345678,
#  '3.5': 0.024691358024691357,
#  'OS': 0.012345679012345678,
#  'com': 0.012345679012345678,
#  'keywords': 0.07407407407407407,
#  'likewise': 0.04938271604938271,
#  'known': 0.037037037037037035,
#  'maintainer': 0.08641975308641975,
#  'huh': 0.04938271604938271,
#  'Capital': 0.012345679012345678,
#  'author': 0.037037037037037035,
#  'maintains': 0.012345679012345678,
#  'different': 0.13580246913580246,
#  'Escape': 0.04938271604938271,
#  'colon': 0.08641975308641975,
#  'WQ': 0.06172839506172839,
#  'class': 0.09876543209876543,
#  'got': 0.04938271604938271,
#  'good': 0.08641975308641975,
#  'scolding': 0.012345679012345678,
#  'telling': 0.024691358024691357,
#  'weak': 0.012345679012345678,
#  'Linux': 0.07407407407407407,
#  'condition': 0.012345679012345678,
#  'week': 0.012345679012345678,
#  'gone': 0.024691358024691357,
#  'progress': 0.012345679012345678,
#  'study': 0.012345679012345678,
#  'press': 0.07407407407407407,
#  'lbo': 0.012345679012345678,
#  'W': 0.037037037037037035,
#  'situation': 0.012345679012345678,
#  'honest': 0.012345679012345678,
#  'limits': 0.012345679012345678,
#  'strong': 0.012345679012345678,
#  'strongs': 0.012345679012345678,
#  'DeVos': 0.012345679012345678,
#  'CO': 0.012345679012345678,
#  'Basics': 0.024691358024691357,
#  'important': 0.06172839506172839,
#  'actually': 0.04938271604938271,
#  'anyways': 0.024691358024691357,
#  'dockerhub': 0.037037037037037035,
#  'username': 0.024691358024691357,
#  'email': 0.012345679012345678,
#  'ID': 0.16049382716049382,
#  'rajeswar': 0.06172839506172839,
#  'SL': 0.037037037037037035,
#  'WR': 0.037037037037037035,
#  'hyen': 0.024691358024691357,
#  'gate': 0.012345679012345678,
#  'dot': 0.04938271604938271,
#  'LS': 0.037037037037037035,
#  'rename': 0.04938271604938271,
#  'D': 0.07407407407407407,
#  'rajes': 0.04938271604938271,
#  'mind': 0.024691358024691357,
#  'words': 0.012345679012345678,
#  'care': 0.024691358024691357,
#  'high': 0.012345679012345678,
#  'course': 0.024691358024691357,
#  'months': 0.012345679012345678,
#  'aware': 0.012345679012345678,
#  'end': 0.012345679012345678,
#  'Shila': 0.037037037037037035,
#  'sha': 0.012345679012345678,
#  'speaking': 0.024691358024691357,
#  'mute': 0.024691358024691357,
#  'anit': 0.08641975308641975,
#  'MV': 0.024691358024691357,
#  'sorry': 0.07407407407407407,
#  'changed': 0.024691358024691357,
#  'new': 0.18518518518518517,
#  'list': 0.012345679012345678,
#  'AR': 0.037037037037037035,
#  'type': 0.012345679012345678,
#  'hit': 0.037037037037037035,
#  'syntax': 0.024691358024691357,
#  'wrong': 0.024691358024691357,
#  'gave': 0.04938271604938271,
#  'error': 0.09876543209876543,
#  'maximize': 0.012345679012345678,
#  'screen': 0.04938271604938271,
#  'layers': 0.13580246913580246,
#  'created': 0.20987654320987653,
#  'pulled': 0.012345679012345678,
#  'updated': 0.012345679012345678,
#  'package': 0.012345679012345678,
#  'giving': 0.04938271604938271,
#  'response': 0.024691358024691357,
#  'demon': 0.024691358024691357,
#  'running': 0.12345679012345678,
#  'service': 0.012345679012345678,
#  'status': 0.012345679012345678,
#  'check': 0.07407407407407407,
#  'rajeswari': 0.037037037037037035,
#  'built': 0.024691358024691357,
#  'SE': 0.012345679012345678,
#  'dotop': 0.012345679012345678,
#  'minute': 0.024691358024691357,
#  'Imes': 0.012345679012345678,
#  'imagees': 0.012345679012345678,
#  'ago': 0.012345679012345678,
#  'ran': 0.024691358024691357,
#  'successfully': 0.012345679012345678,
#  'yes': 0.08641975308641975,
#  'playing': 0.012345679012345678,
#  'bit': 0.012345679012345678,
#  'able': 0.024691358024691357,
#  'start': 0.024691358024691357,
#  'containers': 0.07407407407407407,
#  'execut': 0.012345679012345678,
#  'sh': 0.06172839506172839,
#  'inside': 0.024691358024691357,
#  'understand': 0.024691358024691357,
#  'layering': 0.012345679012345678,
#  'concept': 0.012345679012345678,
#  'runnable': 0.012345679012345678,
#  'instance': 0.024691358024691357,
#  'runable': 0.012345679012345678,
#  'parent': 0.012345679012345678,
#  'read': 0.04938271604938271,
#  'means': 0.07407407407407407,
#  'layer': 0.2962962962962963,
#  'execution': 0.012345679012345678,
#  'added': 0.012345679012345678,
#  'copy': 0.24691358024691357,
#  'adds': 0.024691358024691357,
#  'additional': 0.012345679012345678,
#  'mainly': 0.012345679012345678,
#  'getting': 0.16049382716049382,
#  'creating': 0.08641975308641975,
#  'm': 0.012345679012345678,
#  'called': 0.024691358024691357,
#  'separate': 0.012345679012345678,
#  'path': 0.024691358024691357,
#  'parameter': 0.024691358024691357,
#  '5': 0.012345679012345678,
#  'think': 0.07407407407407407,
#  'saying': 0.04938271604938271,
#  'Shar': 0.012345679012345678,
#  'backup': 0.08641975308641975,
#  'earlier': 0.012345679012345678,
#  'shared': 0.024691358024691357,
#  'bku': 0.012345679012345678,
#  'improve': 0.024691358024691357,
#  'skill': 0.012345679012345678,
#  'sets': 0.012345679012345678,
#  'forget': 0.037037037037037035,
#  'blunt': 0.012345679012345678,
#  'feel': 0.012345679012345678,
#  'bad': 0.024691358024691357,
#  'away': 0.012345679012345678,
#  'bitter': 0.012345679012345678,
#  'truth': 0.012345679012345678,
#  'skills': 0.012345679012345678,
#  'contents': 0.037037037037037035,
#  'apart': 0.024691358024691357,
#  'explain': 0.012345679012345678,
#  'questions': 0.04938271604938271,
#  'completely': 0.024691358024691357,
#  'shows': 0.012345679012345678,
#  'con': 0.012345679012345678,
#  'Focus': 0.024691358024691357,
#  'sake': 0.012345679012345678,
#  'cloud': 0.024691358024691357,
#  'escape': 0.024691358024691357,
#  'ahead': 0.012345679012345678,
#  'B': 0.037037037037037035,
#  'whichever': 0.012345679012345678,
#  'generates': 0.024691358024691357,
#  'unique': 0.012345679012345678,
#  'step': 0.024691358024691357,
#  'generated': 0.012345679012345678,
#  'complete': 0.024691358024691357,
#  'want': 0.04938271604938271,
#  'look': 0.024691358024691357,
#  'helpful': 0.012345679012345678,
#  'history': 0.07407407407407407,
#  '23': 0.012345679012345678,
#  'doger': 0.012345679012345678,
#  'blank': 0.012345679012345678,
#  'ER': 0.024691358024691357,
#  'option': 0.037037037037037035,
#  'demo': 0.012345679012345678,
#  'word': 0.024691358024691357,
#  'repository': 0.024691358024691357,
#  'K': 0.024691358024691357,
#  'contact': 0.024691358024691357,
#  'account': 0.024691358024691357,
#  'instead': 0.06172839506172839,
#  'wet': 0.012345679012345678,
#  'h': 0.037037037037037035,
#  'lower': 0.012345679012345678,
#  'letter': 0.012345679012345678,
#  'required': 0.012345679012345678,
#  'H': 0.024691358024691357,
#  'andila': 0.012345679012345678,
#  'wo': 0.024691358024691357,
#  'works': 0.024691358024691357,
#  'files': 0.024691358024691357,
#  'maybe': 0.012345679012345678,
#  'need': 0.037037037037037035,
#  'working': 0.04938271604938271,
#  'worked': 0.012345679012345678,
#  'difference': 0.024691358024691357,
#  'keyword': 0.037037037037037035,
#  'defining': 0.012345679012345678,
#  'continuously': 0.012345679012345678,
#  'pointing': 0.012345679012345678,
#  'invalid': 0.024691358024691357,
#  'argument': 0.20987654320987653,
#  'cled': 0.012345679012345678,
#  'use': 0.04938271604938271,
#  '1': 0.04938271604938271,
#  '2': 0.07407407407407407,
#  '3': 0.037037037037037035,
#  'Raj': 0.012345679012345678,
#  'took': 0.012345679012345678,
#  'saw': 0.04938271604938271,
#  'seeing': 0.012345679012345678,
#  'sweet': 0.012345679012345678,
#  'thank': 0.037037037037037035,
#  'hist': 0.012345679012345678,
#  'spelling': 0.024691358024691357,
#  'History': 0.012345679012345678,
#  'sir': 0.012345679012345678,
#  'alpide': 0.012345679012345678,
#  'identify': 0.012345679012345678,
#  'visualize': 0.037037037037037035,
#  'asking': 0.037037037037037035,
#  'V': 0.04938271604938271,
#  '123': 0.012345679012345678,
#  'cre': 0.012345679012345678,
#  'slash': 0.012345679012345678,
#  'hyph': 0.012345679012345678,
#  'given': 0.04938271604938271,
#  'test': 0.06172839506172839,
#  'hello': 0.06172839506172839,
#  'happened': 0.024691358024691357,
#  'touch': 0.04938271604938271,
#  'man': 0.024691358024691357,
#  'Tex': 0.012345679012345678,
#  'simple': 0.012345679012345678,
#  'o': 0.012345679012345678,
#  'u': 0.012345679012345678,
#  'c': 0.012345679012345678,
#  'TC': 0.012345679012345678,
#  'T': 0.012345679012345678,
#  'Test': 0.012345679012345678,
#  'viralized': 0.012345679012345678,
#  'replace': 0.024691358024691357,
#  'second': 0.012345679012345678,
#  'waiting': 0.024691358024691357,
#  'Mr': 0.012345679012345678,
#  's': 0.012345679012345678,
#  'doy': 0.012345679012345678,
#  'RM': 0.012345679012345678,
#  'visualiz': 0.012345679012345678,
#  'remove': 0.037037037037037035,
#  'Explorer': 0.012345679012345678,
#  'opens': 0.012345679012345678,
#  'rmus': 0.012345679012345678,
#  'mapping': 0.012345679012345678,
#  'volume': 0.04938271604938271,
#  'visualization': 0.012345679012345678,
#  'link': 0.012345679012345678,
#  'CMD': 0.037037037037037035,
#  'brackets': 0.024691358024691357,
#  'entry': 0.07407407407407407,
#  'di': 0.037037037037037035,
#  'current': 0.012345679012345678,
#  'specified': 0.012345679012345678,
#  'root': 0.012345679012345678,
#  'mean': 0.024691358024691357,
#  'Applause': 0.012345679012345678,
#  'says': 0.037037037037037035,
#  'bin': 0.012345679012345678,
#  'Eco': 0.04938271604938271,
#  'cont': 0.012345679012345678,
#  'label': 0.024691358024691357,
#  'tells': 0.012345679012345678,
#  'comfort': 0.012345679012345678,
#  'laptop': 0.012345679012345678,
#  'currently': 0.012345679012345678,
#  'electricity': 0.012345679012345678,
#  'hours': 0.012345679012345678,
#  'joined': 0.012345679012345678,
#  'Mobile': 0.012345679012345678,
#  'Sila': 0.012345679012345678,
#  'sain': 0.012345679012345678,
#  'login': 0.012345679012345678,
#  'rajar': 0.012345679012345678,
#  'coming': 0.012345679012345678,
#  'writing': 0.024691358024691357,
#  'doctor': 0.012345679012345678,
#  'lot': 0.012345679012345678,
#  'examples': 0.012345679012345678,
#  'previous': 0.037037037037037035,
#  "ma'am": 0.012345679012345678,
#  'F': 0.012345679012345678,
#  'properly': 0.024691358024691357,
#  'WoW': 0.012345679012345678,
#  'renaming': 0.012345679012345678,
#  'Mo': 0.012345679012345678,
#  'hey': 0.012345679012345678,
#  'waste': 0.012345679012345678,
#  'repace': 0.012345679012345678,
#  'Command': 0.012345679012345678,
#  'verify': 0.012345679012345678,
#  'soon': 0.012345679012345678,
#  'passed': 0.012345679012345678,
#  'executes': 0.024691358024691357,
#  'hash': 0.037037037037037035,
#  'Echo': 0.012345679012345678,
#  'remember': 0.012345679012345678,
#  'result': 0.012345679012345678,
#  'quickly': 0.024691358024691357,
#  'present': 0.012345679012345678,
#  'TI': 0.012345679012345678,
#  'metadata': 0.012345679012345678,
#  'information': 0.024691358024691357,
#  'Okay': 0.012345679012345678,
#  'sear': 0.012345679012345678,
#  'document': 0.024691358024691357,
#  'worry': 0.024691358024691357,
#  'instru': 0.012345679012345678,
#  'runs': 0.012345679012345678,
#  'directly': 0.012345679012345678,
#  'multiple': 0.012345679012345678,
#  'happen': 0.012345679012345678,
#  'user': 0.08641975308641975,
#  'messages': 0.012345679012345678,
#  'existing': 0.012345679012345678,
#  'greater': 0.012345679012345678,
#  'symbol': 0.012345679012345678,
#  'SP': 0.012345679012345678,
#  'deleting': 0.024691358024691357,
#  'nullify': 0.024691358024691357,
#  'delete': 0.037037037037037035,
#  'control': 0.037037037037037035,
#  'taking': 0.012345679012345678,
#  'shpa': 0.012345679012345678,
#  'oh': 0.024691358024691357,
#  'proper': 0.024691358024691357,
#  'copied': 0.012345679012345678,
#  'starts': 0.012345679012345678,
#  'God': 0.012345679012345678,
#  'es': 0.012345679012345678,
#  'Double': 0.012345679012345678,
#  'deleted': 0.012345679012345678,
#  'tomorrow': 0.08641975308641975,
#  'situations': 0.012345679012345678,
#  'notepad': 0.024691358024691357,
#  'world': 0.024691358024691357,
#  '3.9.3': 0.012345679012345678,
#  'cat': 0.037037037037037035,
#  'copying': 0.012345679012345678,
#  'correctly': 0.012345679012345678,
#  'great': 0.024691358024691357,
#  'Shilpa': 0.012345679012345678,
#  'welcome': 0.09876543209876543,
#  'collab': 0.024691358024691357,
#  'NEX': 0.012345679012345678,
#  'message': 0.024691358024691357,
#  'printed': 0.012345679012345678,
#  'print': 0.012345679012345678,
#  'col': 0.012345679012345678,
#  'defined': 0.012345679012345678,
#  'B1': 0.012345679012345678,
#  'V1': 0.012345679012345678,
#  'options': 0.012345679012345678,
#  'value': 0.012345679012345678,
#  'V2': 0.024691358024691357,
#  'real': 0.012345679012345678,
#  'ARG': 0.012345679012345678,
#  'suchin': 0.012345679012345678,
#  'came': 0.012345679012345678,
#  'arguments': 0.012345679012345678,
#  'versions': 0.012345679012345678,
#  'set': 0.012345679012345678,
#  'varieties': 0.012345679012345678,
#  'mechanisms': 0.012345679012345678,
#  'place': 0.012345679012345678,
#  'accordingly': 0.012345679012345678,
#  'formats': 0.012345679012345678,
#  'big': 0.024691358024691357,
#  'stuff': 0.012345679012345678,
#  'ways': 0.012345679012345678,
#  'GitHub': 0.012345679012345678,
#  'links': 0.012345679012345678,
#  'hour': 0.024691358024691357,
#  'preponing': 0.012345679012345678,
#  'Class': 0.012345679012345678,
#  '3:00': 0.012345679012345678,
#  'having': 0.012345679012345678,
#  'p.m.': 0.024691358024691357,
#  'private': 0.04938271604938271,
#  'registry': 0.07407407407407407,
#  'networking': 0.037037037037037035,
#  'volumes': 0.012345679012345678,
#  'yesterday': 0.012345679012345678,
#  'public': 0.012345679012345678,
#  'open': 0.012345679012345678,
#  'probably': 0.012345679012345678,
#  'exposed': 0.012345679012345678,
#  'corporates': 0.012345679012345678,
#  'remind': 0.012345679012345678,
#  'ECR': 0.012345679012345678,
#  'elastic': 0.012345679012345678,
#  'y': 0.012345679012345678,
#  'finish': 0.012345679012345678,
#  'started': 0.024691358024691357,
#  'inspect': 0.012345679012345678,
#  'access': 0.012345679012345678,
#  'shell': 0.012345679012345678,
#  'components': 0.012345679012345678,
#  'understander': 0.012345679012345678,
#  'session': 0.037037037037037035,
#  'shouting': 0.012345679012345678,
#  'find': 0.012345679012345678,
#  'especially': 0.012345679012345678,
#  'difficult': 0.012345679012345678,
#  'learned': 0.024691358024691357,
#  'spring': 0.012345679012345678,
#  'boot': 0.024691358024691357,
#  'owning': 0.012345679012345678,
#  'joining': 0.012345679012345678,
#  'cope': 0.012345679012345678,
#  'recorded': 0.012345679012345678,
#  'sessions': 0.012345679012345678,
#  'times': 0.012345679012345678,
#  'practice': 0.012345679012345678,
#  'assignment': 0.012345679012345678,
#  'notes': 0.012345679012345678,
#  'occupied': 0.012345679012345678,
#  'office': 0.012345679012345678,
#  'meet': 0.012345679012345678,
#  'IST': 0.012345679012345678,
#  'wrap': 0.012345679012345678,
#  'thanks': 0.012345679012345678}

# %% [markdown]
# ### Task 8: Calculate Score of Sentences

# %%
sentence_tokens = [sentence for sentence in document.sents]
sentence_score = {}
for sentence in sentence_tokens:
    for word in sentence:
        if word.text.lower() in word_frequencies.keys():
            if sentence not in sentence_score.keys():
                sentence_score[sentence] = word_frequencies[word.text.lower()]
            else:
                sentence_score[sentence] += word_frequencies[word.text.lower()]
sentence_score
# Out:
# { if I have to share or if I have to do any kind of you know the image of something: 1.0987654320987654,
#  so how can I save it any idea so far we talked about doer Hub we talked about how to run a container how to do the image and all those parts and things now my question is if I have to talk about the that we also talked about that how we can build a image and push it to the docker Hub uh now my question is that if I have to talk about that how can we save the image and the container as a tire file or something we talked about this: 7.234567901234568,
#  right: 0.7530864197530864,
#  yeah we can save it how you told with the command uh like Docker save with this we can save our image as a t file: 4.679012345679011,
#  yeah: 0.7037037037037037,
#  Docker export Docker save command: 1.4814814814814814,
#  okay: 0.8395061728395061,
#  yeah those are the two command through which we can do this now today we are going to talk about the docker file okay guys what is Docker file and how does it work in these things right the docker file is nothing it's a text file you know which contains like whatever now the operations you have performed all those operations you are putting up in a text file and jotting down it together: 10.666666666666663,
#  okay that is your Docker file: 2.0987654320987654,
#  okay now those instructions are nothing you know it is basically you execute those instructions you write in the particular order and that is how it is written: 1.6419753086419755,
#  and it creates the images and these things now let's say that if we have to create a image where you have to install a git: 2.0617283950617282,
#  right: 0.7530864197530864,
#  what you do you write Docker build G or Docker image git you will pull and then run the container correct correct: 3.2469135802469133,
#  yeah: 0.7037037037037037,
#  yeah: 0.7037037037037037,
#  now what in our case what I'm am going to do is that I have to run or I have to install the git so for that let's say I will install a operating system name as Alpine what I'll do: 1.382716049382716,
#  I'll install the operating system Alpine: 0.16049382716049382,
#  and I will write that: 0.345679012345679,
#  okay: 0.8395061728395061,
#  how can I install the git now you see this is a example of a Docker file: 1.5185185185185186,
#  okay I will write Run apk update and Run apk G Now APK add G APK update are what those are the two commands for operating system: 3.2962962962962967,
#  okay now you can change it based on the ubu based on any other thing correct: 1.1604938271604937,
#  yeah now once it is done then we can do what we can build this image how we can build using a Docker build command: 3.407407407407407,
#  and we can further tag the image where the things are there now once this is done we can create a container and do the things this will help me to do all the things now the point is how can we build a image how can we do all the steps so create a Docker file go to the server or wherever Docker is installed go: 5.666666666666667,
#  [Music] there do like I have done through AWS awss: 0.3333333333333333,
#  okay: 0.8395061728395061,
#  yeah: 0.7037037037037037,
#  right do minus minus version enter: 1.3703703703703702,
#  okay uh do do PWD go to any home directory right CD hyphen: 1.950617283950617,
#  hyphen just write hyy C: 0.4074074074074074,
#  Hy CD space Hy enter: 0.38271604938271603,
#  okay: 0.8395061728395061,
#  so okay: 0.8395061728395061,
#  that is let just do CD and enter okay home directory that on fine: 1.3703703703703702,
#  no problem now here write VI Docker file in capital Docker file scho I write down the paste down the those three commands which I have done sent [Music] over I didn't get you what you said in the chat window the content of a Docker file: 5.098765432098766,
#  right: 0.7530864197530864,
#  okay um listen from Alpine: 0.8641975308641976,
#  yeah: 0.7037037037037037,
#  okay: 0.8395061728395061,
#  P there and then hold on I'll tell you what now with this there is one question in the interview which is asked most of the time that what are the default parameters or the attributes or you know the instruction which you have to pass when you write a dogger file now from is what from will tell you that which image has to be used okay Alpine colum 3.5 is what this a image of Alpine OS with version 3.5 run is a command to run the com this any commands and anything right that is one instruction so from run all these are keywords here: 9.530864197530864,
#  okay these are the instruction we'll see further more as: 1.0864197530864197,
#  and then we will move likewise we have one instruction by which is known as maintainer what it is known as maintainer maintainer those keywords should be in a capital or anything huh those keywords run Capital all capital maintainer is also something which is the author okay after maintainer you can give author which will tell you that maintains this file so likewise you have different other parameters which we will talk about: 4.493827160493827,
#  okay now save this file: 2.0,
#  okay now Escape colon [Music] WQ see last class only you guys got a good one from like not like any kind of a scolding or something: 2.160493827160494,
#  but I was telling you guys last class also that you guys are so weak in Linux so far but still you guys are in the same condition one week gone no progress this show that no study done Escape press Escape now press colon WQ lbo W WQ enter if this would be the situation I'm telling you guys to be honest you have to make your limits very strong if you don't have your Linux strongs any interview go for DeVos interview you go for a CO interview Linux Linux Basics are very important these are are Basics: 2.333333333333333,
#  [Music] actually anyways write a command Docker space build space minus t space now give your dockerhub username here email ID that's okay give rajeswar only SL WR Alpine hyen gate hyen hyphen space dot: 3.864197530864198,
#  [Music] do do LS here for do one thing move rename the docker file with the only capital D as a [Music] capital hold on how hold on hold on except rajes no one else will tell this to me how can we rename the file in Linux guys if you mind my words right now I don't care mind it: 4.185185185185185,
#  but it's high time we are doing this course from last three months we are not aware of the command so far we are almost at the end of the course now Shila what is the command to rename the file sha if you're speaking you're speaking on mute with help what is the command: 3.9012345679012346,
#  most anit: 0.08641975308641975,
#  yeah MV command with the help of command: 2.3580246913580245,
#  sorry I was on mute: 0.09876543209876543,
#  yeah: 0.7037037037037037,
#  as now you get the command write MV space give this Docker file name the file which has to be changed the file which has to be changed space a new name what is this I space the new name of the file which has to be written enter: 6.62962962962963,
#  yeah do LS list out the file now you see the change run that Docker build command again: 3.8888888888888884,
#  okay: 0.8395061728395061,
#  and press up AR why don't why you have to type it over again and again: 0.08641975308641975,
#  yeah hit enter now you see so the syntax of the docker file name was wrong that's why it gave you that error: 2.395061728395062,
#  okay maximize your screen here what it has done it has basically installed everything with this layers right it has created you know pulled a image in updated the package in my case it is giving error same: 3.2716049382716057,
#  okay: 0.8395061728395061,
#  what error uh error response from demon is not running then service status Docker: 0.8518518518518519,
#  yeah now how can you check uh rajeswari that whether the image has built or not it is running running running SE t dotop hold on one minute: 2.432098765432099,
#  yeah: 0.7037037037037037,
#  how will you check rajeswari what we have to check image you have created right whether the image is installed or not Imes you have the command: 3.6543209876543212,
#  right: 0.7530864197530864,
#  and you have this thing also you see the imagees created right about a minute ago: 1.123456790123457,
#  yeah: 0.7037037037037037,
#  so we have this image already created now: 1.0493827160493827,
#  right so your command ran successfully correct: 1.6666666666666665,
#  yeah: 0.7037037037037037,
#  yes: 0.08641975308641975,
#  okay we have been playing around with doer for quite a bit now we were able to start containers and execut a sh inside those containers now the whole point of thing here is that we have to understand this image layering concept okay in the docker file which is again very very important part each and every Docker file which is running here that is what that is a runnable instance of an image right that is a runable instance of an image which is basically how which is basically being done by some more other this: 8.50617283950617,
#  right the uh image layers and these things now the point is that when you create a parent image or you create an image from a Docker file: 6.012345679012346,
#  okay the that image is only a read only right means when you create an image: 3.7283950617283947,
#  so or when you run this Docker file it creates some different layers right every command is done via the layer execution means then you have each and every image or each and everything in a Docker file in a read only and whatever the instruction whatever the things you give for those that is being added and all those those layers are created and these are D when you run the command now the instructions like from run copy add and all those things: 10.876543209876544,
#  okay those adds you to the additional layer mainly the instruction like run copy and add those will help you to add a new layer getting it: 3.753086419753086,
#  yeah now every layer is read only except the one which is creating a container: 1.3703703703703702,
#  okay the m is the last layer the last layer is called a container layer what is called container layer now example if you run this create another Docker file now if you have to create a separate Docker file you have to give the either change the path and then created okay for now otherwise you have to give a parameter minus 5: 8.024691358024691,
#  and I think do five: 0.07407407407407407,
#  okay: 0.8395061728395061,
#  so this one you're saying this command which you: 0.8395061728395061,
#  huh yeah make a backup of that Docker file which you created earlier and create a new Docker file with the command which I shared right here have to make a backup: 5.753086419753087,
#  huh how to make a backup P move command you have to write the move command move Docker file and write docker file.: 4.925925925925926,
#  bku very good rajeswar improve your skill sets otherwise forget run this command I'll be very blunt you might feel it bad right away but this is a you know a bitter truth you have to improve your Linux operating skills: 2.864197530864198,
#  yeah that command in the chat window now create a new Docker file with the new content which I put out what you are doing how can you create a new file VI Docker file D capital D capital of Docker file enter paste the contents here now guys in this one you see more instructions right apart from from run add you see that how it is copy and all those things are there getting it guys anything to explain any questions no save this how can you save this we did just before sometime in the class that completely shows how con uh with what Focus we are doing it if we are doing just only for sake of running in the cloud that doesn't going to help you escape colon WQ correct very good go ahead build a image with this one: 13.691358024691354,
#  [Music] now change the name of the image now got no problem forget about the copy file right now others has been B done right now every instruction of the docker file whichever you run that has a layer ID every layer generates a unique layer ID if you see with the step one here it generated a layer ID after that full complete right this: 8.17283950617284,
#  [Music] one step two this one again generates a layer ID getting it: 0.5061728395061729,
#  yeah now creating now if you want to look over all these layers of these things together now these layers are like again it's all over creating image but the layers are also helpful: 2.8641975308641974,
#  right so write a command Docker history and Docker 23 name Docker space enter WR Docker: 3.395061728395061,
#  [Music] images was okay write doger history with the blank space for everyone is it the same: 1.6419753086419755,
#  yeah for me it is: 0.7037037037037037,
#  demon ER let's see your error also meanwhile rajes look for the option and tell me what is the option share screen for this also it is giving error response from demo: 0.9135802469135801,
#  yeah: 0.7037037037037037,
#  what word your name is the same the docker file is not the name right first of all check your repository name: 2.1358024691358026,
#  no check your repository name with K contact is it: 0.12345679012345678,
#  the dockerhub account name: 0.06172839506172839,
#  yeah: 0.7037037037037037,
#  yeah: 0.7037037037037037,
#  yeah: 0.7037037037037037,
#  now where do Docker file give SL example Alpine or something then do instead of Docker file just write example get or something tell me Docker build minus t wet K contact SL example git dot: 4.34567901234568,
#  this one h this is what is the problem it is that lower case letter is required I think I'm that anit what is the what was the problem here in the command H: 1.2716049382716048,
#  yeah he gave the docker file name instead of the image name andila why this Docker file name Docker file won't work why other name will work uh it works on the images only instead of files no rajes maybe we need to go to the directory again and create new what was my question that why there is not working the command: 7.962962962962964,
#  h: 0.037037037037037035,
#  but now it worked right but had be a difference only the change in the name the docker file is a keyword guys: 2.4444444444444446,
#  yeah: 0.7037037037037037,
#  yeah: 0.7037037037037037,
#  so it's not how can it take you are defining a Docker file with that right anit: 2.111111111111111,
#  but it is continuously it's pointing with invalid argument and giving the argument there for minus t okay not getting the error if any keyword is cled with any it will take it as a invalid any keyword if I use Docker 1 2 3 then also take it will take ER because Raj took I think doer 2 three it is: 2.654320987654321,
#  okay it won't give you error at that time tell: 1.1851851851851851,
#  okay it ran now now you see the layer you saw all the things that's okay now: 2.382716049382716,
#  so for seeing all the history of that and these things run Docker history and run Docker images [Music] no run: 3.5555555555555554,
#  [Music] Docker it's sweet thank you done the docker: 0.5679012345679012,
#  [Music] history and give the image ID hist is spelling is it the right spelling of History image ID first one first one image ID sir the one which you created right now this is what you created [Music] right getting it guys three different layers has been were part of this right do history and copy the image of [Music] alpide see this: 8.074074074074073,
#  okay anyways: 0.8641975308641975,
#  and we get got it how this layers and how this layer is created the each and every layer is nothing it is a part: 0.9876543209876543,
#  [Music] of this thing: 0.1111111111111111,
#  okay each and every command every instruction which you write in a Docker container that is almost a part of Docker layer getting it: 3.4320987654320985,
#  yeah: 0.7037037037037037,
#  so these are the means how can you identify read and WR layer here very good now the command to visualize the docker layer: 1.9012345679012346,
#  right so what anit is asking is that how can I visualize the layers so the command to visualize the layers is run this command like don't run this command just copy and paste this command and do space and write at your W 1 2 three example I'm saying don't run the command just paste that [Music] command there and do space write your that V so 123: 10.493827160493826,
#  whatever it is cre slash example G example hyph get whatever the name you have given enter [Music] then we have to give the image name give the image ID rather than: 2.2098765432098766,
#  that space image: 1.0246913580246912,
#  [Music] ID where should I instead of the example: 0.18518518518518517,
#  ID then a command Docker build minus 3 test image do space enter now done Docker images create that copy file create a file hello.: 6.234567901234568,
#  [Music] text what happened create a file with the name is hello.: 1.4938271604938271,
#  text: 0.07407407407407407,
#  yeah: 0.7037037037037037,
#  I was creating that only file created no it is not created why I create a file the touch command man just write touch: 4.098765432098766,
#  hello Tex simple command I'm not getting what you asking write touch command t o u c h touch space: 2.6296296296296298,
#  hello.: 0.06172839506172839,
#  TC enter [Music] now that done run the build command again this one: 2.0493827160493825,
#  huh Docker images what is the image name what is the image name guys test image T Test image now run that viralized command and replace the ID with the test image second three for whom you are waiting for Mr with: 6.888888888888889,
#  yeah: 0.7037037037037037,
#  what what you said s an what I have asked to do run that do command again doy RM the visualiz command run that remove the ID give test image enter sorry remove that uh your with Explorer G complete right run this what it has done it opens the sh like: 6.666666666666667,
#  but this is a command Docker run minus rmus it minus V that is doing nothing it is mapping the volume volume of server to the cloud: 2.382716049382717,
#  okay: 0.8395061728395061,
#  I'll check why this command is not working but command work: 1.9012345679012346,
#  okay visualization: 0.8518518518518519,
#  but I'll take care: 0.024691358024691357,
#  okay any question so far: 1.0123456790123457,
#  [Music] so let's create an image right with an instruction add: 2.4814814814814814,
#  yeah tell me what you are asking what I'm: 0.8518518518518519,
#  yeah we saw run instruction we saw add instruction we saw copy instruction so far correct in Docker file any problem with that like uh there are some keywords in Docker file right these keywords you are using from run so where we can get more keywords like which we can get through the some other link okay instruction known as command H CMD which you pass in the brackets: 10.209876543209875,
#  and you write there like this CMD is nothing that is a command right that: 2.2098765432098766,
#  okay once you install the image and everything run this command top getting it: 3.4938271604938267,
#  yeah now let's move on to the next instruction entry point work di directory something that is a current image: 2.530864197530864,
#  okay if it is not specified and the default path is root: 0.9876543209876543,
#  [Music] getting it: 0.16049382716049382,
#  yeah: 0.7037037037037037,
#  likewise we have entry point entry point mean that when the things has to work [Music]: 1.0246913580246912,
#  [Applause] now here if you see is this instruction point or entry point what does it says says that go to the bin Eco and there Eco this cont: 0.691358024691358,
#  right you see label maintainer that tells you the build this image anit now it's your done you share your screen and let's see how much comfort would you have so far actually I am not working on laptop currently no electricity P: 2.6790123456790127,
#  two hours so I joined from Mobile today: 0.08641975308641975,
#  yeah sain show me how you will build this image I didn't login at all first of all rajar coming back to [Music] you share your screen writing doctor file is very very important I'll share you a lot of examples also for this create a Docker file take the backup of previous one save this file ma'am rajeswar what happened what you are waiting for [Music] correct now build a image first of all do you have given a name itself wrong you have to give a name at Docker file right you cannot give if you're giving a different name then you have to pass the parameter with minus F and this: 10.000000000000004,
#  and it sometime doesn't work properly WoW instead of renaming you what you are doing did you do the backup of previous one you got it: 0.4691358024691358,
#  yes we have to using Mo command we have to rename [Music] that you build of the image: 2.037037037037037,
#  hey rajeswari sorry man' but let me write you the commands that we can't waste time for everyone here: 0.9753086419753085,
#  right sorry use this command repace those commands no no B basically hold on first use this command you didn't put the backup also first use this command then run that command and then run the other Command: 6.91358024691358,
#  right yes now run other commands so you see this build a image: 2.91358024691358,
#  right this has built a image a Docker image now let's run this container now do Docker image LS let's see how it is let's verify the [Music] image new test image is there right which I have created now run this run a container as soon as you run a container you will: 11.148148148148149,
#  yeah what you said container copy paste a command now you see we have passed this entry point instruction: 2.5925925925925926,
#  right that whenever it executes whenever run give execute this right hash B Echo remember: 2.3950617283950617,
#  yeah: 0.7037037037037037,
#  yeah is the result of the same: 0.7160493827160495,
#  only okay now let's talk about quickly the work di right the work di means the work directory instructions which says that whatever the command you are going to run that has to be run from this directory: 5.469135802469136,
#  okay that is a present working directory now the whole problem with this is that sorry the whole part with this is that it doesn't create any new layer: 1.9753086419753083,
#  okay like run add copy those creates new layer right work TI doesn't create any new layer but it just adds a metadata information or it just add the information of this into the docker: 5.098765432098764,
#  that okay this work directory has to be used for running the other commands: 1.4320987654320985,
#  Okay Shila any questions so far no sear: 1.0123456790123457,
#  yeah: 0.7037037037037037,
#  I'll share the document also for all this don't worry guys okay don't worry about that now this run instru right runs instruction is something which executes and which creates a new layer now run can be in two parts right the Run can be done in a two parts one is you can directly write this like like like this run and whatever the command is there the same command or sometimes you write in the brackets and all those with the other syntax also getting it: 10.358024691358024,
#  yeah if you have to run multiple instructions together at once only you can run like this [Music] also sometimes what happen that you have to create a image with an argument what you have to create an image with an argument example you are creating a image of a Docker file okay where you want to Eco the user: 8.765432098765432,
#  okay you want to Eco the user and show some messages: 0.9876543209876543,
#  okay now everyone sh sh saying rajes take a backup of a existing Docker file quickly hit enter hit enter: 2.9135802469135808,
#  right yes by right now do V now do one thing now do not VI do greater than symbol SP Docker file this will remove the contents of the file without deleting the file okay guys this will nullify the file nullify means this will delete the contents of the file without deleting the file Docker file is one name with the D capital and a Docker and the file together enter now do write VI Docker file enter copy paste the one which I have put in the chat window: 14.493827160493828,
#  yeah control a control C control V that is also taking time for us now you see anit shpa with Focus here the first argument you see what it is argument: 1.4691358024691359,
#  okay what it is argument: 1.0493827160493827,
#  oh yeah: 0.7283950617283951,
#  she copy is not proper you have not even just a yeah not copied the things proper hash you're saying before hash now from the docker file starts from a from the first instruction from to everyone delete everything else in the file: 4.0246913580246915,
#  yeah: 0.7037037037037037,
#  oh my God like this you can't delete this put right es press escape and just press Double D keep going like that until everything is [Music] deleted guys today I'm there tell you the commands tomorrow in the interview no one will be there you think about yourselves situations what is the problem rajeswar here in the copy copy the thing in the notepad from the world which is written from Alpine colon 3.9.3 copy the thing there do until CMD cat. text copy the things in the notepad first me see if you're copying it correctly or not great now right now here you see in the maintainer if you guys want you can replace it with your name it is a author name: 5.938271604938271,
#  okay Shilpa and other guys here I have given argument one as a welcome user collab NEX you can give other welcome user also and what you are doing you're writing a command that is cat message.: 2.666666666666667,
#  text means this instructions right the cat me this instruction which is printed here right welcome an argument name welcome user to the docker world this will go to this and once you create a container or run a container it will print you the message save this file: 5.604938271604939,
#  okay run this command to build guys Escape col WQ save run that command copy paste now we had defined already a Docker default option here right after argument colon B1 just press dot just write dot Docker file it has to now we have created an image here right now run this command which will run the container we have created an image with the argument name as a image and V1 is what my version of a image now this time I'm running the image with a default options okay with a default argument on so it gave me a default username that is welcome user: 18.444444444444446,
#  what uh to welcome collab to the docker word because default was that now let's say that how we can run with that so when you have copy paste a command when you have to run the image where you have to pass the welcome user argument name or you have to give the value to that you have to give minus minus build minus argument what you have to give minus minus build argument so you see in the command it is written right copy paste that now run the image again and this time you see I have created a version two of the images AR colon V2: 11.037037037037036,
#  this is how you work in the real time just write Docker run ARG AR colon V2 it is run run right now you see it gave me welcome suchin why because I have given the build argument came different this is how you can build the images with your own arguments this is how you can run the images with your own argument and with the different versions getting my point: 7.049382716049383,
#  yes: 0.08641975308641975,
#  yes likewise we have a different set of varieties and you know mechanisms and a place through which you can talk: 0.5925925925925926,
#  and you can work upon accordingly I'll share you the different formats of a Docker file: 1.728395061728395,
#  but again you have to go through more big big Docker files and stuff you have to write you have to see that different instruction which we pass like from run copy add and all those things and this is how this works there are the things which creates a layer there are things which doesn't everything is in a document which will be shared with you so that you understand how the docker file is written and how it is created with a different different ways and I'll sh few GitHub links which will give you other things also getting it: 6.45679012345679,
#  yeah so far any questions now in the next class that is tomorrow the class will be only of 1 hour: 1.2222222222222223,
#  okay: 0.8395061728395061,
#  and I'm preponing a Class 1 hour before as I have to go somewhere at around 3:00: 0.19753086419753085,
#  so we'll be having a 2 to 3 only so 2: p.m.: 0.2222222222222222,
#  I actually tomorrow class okay just for tomorrow so fine with you guys right: 2.234567901234568,
#  yeah now we will be doing what that we will be creating a private Docker registry tomorrow we'll talk about a Docker networking and Docker volumes the other three important things we'll talk about that how we can create a private Docker registry: 3.2592592592592586,
#  okay: 0.8395061728395061,
#  right now whatever the docker registry mean Docker Hub W part which we did yesterday in last class that was my public registry which was open to everyone probably right by default private we will create so that it will be exposed to us only no one else can see it: 2.839506172839507,
#  okay like you do in the corporates then we talk about Docker volume and then we'll talk about Docker networking and if I forget just remind me that how can I talk about the ECR that is elastic container registry which is in AWS: 2.6296296296296298,
#  okay: 0.8395061728395061,
#  y: 0.012345679012345678,
#  yeah will finish my okay Docker completely tomorrow we talked about so far that how we can we started with creating a dockerhub account we started with running a container running the images how you can work with the images create the images save the images how you can uh push it to the Hub then we move to the containers we talked about how we can run the containers what's the difference between the few commands of the containers how we can inspect the images and the containers can get the other attributes how we can access the container shell or go inside the container how we can run the commands and all those things and these things and then we talked about the docker file today we talked about the you know the uh we're going to talk about Docker volume Docker networking and private Docker registry these are the few components which are very very important for the docker to start with and to understander: 11.580246913580247,
#  so how are guys how was session apart from my shouting any other thing I really find it very bad that when you guys don't work with the commands properly especially rajeswar for you this is something you have to very: 1.2839506172839508,
#  yeah I need to go through the commands again have to otherwise very difficult for you: 0.9259259259259258,
#  hello: 0.06172839506172839,
#  okay how was the session anit and something: 0.9629629629629628,
#  new: 0.18518518518518517,
#  yeah: 0.7037037037037037,
#  yeah: 0.7037037037037037,
#  I it was very good session: 0.12345679012345678,
#  I learned so many like Docker file commands which we used to run like run command entry point and label all these things actually I did one spring boot on this only Docker file so with with that also like I learned three to four commands how to create our owning boot image: 8.11111111111111,
#  great Shila I think you are joining first class of today's do so you are able to cope up get it: 0.30864197530864196,
#  yeah: 0.7037037037037037,
#  yeah: 0.7037037037037037,
#  I have gone through previous recorded sessions I am uh yeah getting it: 1.1481481481481481,
#  yeah I need to go through it uh one or two times more again: 0.9506172839506173,
#  okay thank you: 0.8765432098765431,
#  but any questions from you: 0.04938271604938271,
#  yes it is new for me I have to go to yeah more and more practice will help us to do this I'll share you guys the assignment and other things also everything for this I have a very good notes please like this I'm quite occupied with some of you know: 2.3580246913580245,
#  office: 0.012345679012345678,
#  but I'll share with you guys: 0.4074074074074074,
#  okay: 0.8395061728395061,
#  so I think we are good with the things: 0.49382716049382713,
#  okay let's meet up again tomorrow same time same sorry 2 p.m. IST and uh let's wrap up Docker: 2.0617283950617282,
#  and then we'll talk about further things: 0.49382716049382713,
#  okay thank you: 0.8765432098765431,
#  yeah: 0.7037037037037037,
#  okay: 0.8395061728395061,
#  thanks guys: 0.30864197530864196}

# %% [markdown]
# ### Task 9: Generate the Summary

# %%
select_length = int(len(sentence_tokens) * 0.3)
summary = nlargest(select_length, sentence_score, key = sentence_score.get)
final_summary = [word.text for word in summary]
summary = ' '.join(final_summary)
summary
# Out:
# "okay run this command to build guys Escape col WQ save run that command copy paste now we had defined already a Docker default option here right after argument colon B1 just press dot just write dot Docker file it has to now we have created an image here right now run this command which will run the container we have created an image with the argument name as a image and V1 is what my version of a image now this time I'm running the image with a default options okay with a default argument on so it gave me a default username that is welcome user right yes by right now do V now do one thing now do not VI do greater than symbol SP Docker file this will remove the contents of the file without deleting the file okay guys this will nullify the file nullify means this will delete the contents of the file without deleting the file Docker file is one name with the D capital and a Docker and the file together enter now do write VI Docker file enter copy paste the one which I have put in the chat window yeah that command in the chat window now create a new Docker file with the new content which I put out what you are doing how can you create a new file VI Docker file D capital D capital of Docker file enter paste the contents here now guys in this one you see more instructions right apart from from run add you see that how it is copy and all those things are there getting it guys anything to explain any questions no save this how can you save this we did just before sometime in the class that completely shows how con uh with what Focus we are doing it if we are doing just only for sake of running in the cloud that doesn't going to help you escape colon WQ correct very good go ahead build a image with this one yeah will finish my okay Docker completely tomorrow we talked about so far that how we can we started with creating a dockerhub account we started with running a container running the images how you can work with the images create the images save the images how you can uh push it to the Hub then we move to the containers we talked about how we can run the containers what's the difference between the few commands of the containers how we can inspect the images and the containers can get the other attributes how we can access the container shell or go inside the container how we can run the commands and all those things and these things and then we talked about the docker file today we talked about the you know the uh we're going to talk about Docker volume Docker networking and private Docker registry these are the few components which are very very important for the docker to start with and to understander right this has built a image a Docker image now let's run this container now do Docker image LS let's see how it is let's verify the [Music] image new test image is there right which I have created now run this run a container as soon as you run a container you will what uh to welcome collab to the docker word because default was that now let's say that how we can run with that so when you have copy paste a command when you have to run the image where you have to pass the welcome user argument name or you have to give the value to that you have to give minus minus build minus argument what you have to give minus minus build argument so you see in the command it is written right copy paste that now run the image again and this time you see I have created a version two of the images AR colon V2 so or when you run this Docker file it creates some different layers right every command is done via the layer execution means then you have each and every image or each and everything in a Docker file in a read only and whatever the instruction whatever the things you give for those that is being added and all those those layers are created and these are D when you run the command now the instructions like from run copy add and all those things yeah those are the two command through which we can do this now today we are going to talk about ...
